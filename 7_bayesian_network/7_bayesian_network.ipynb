# %% [markdown]
# # 7 : Construct a Bayesian Network to demonstrate the diagnosis of heart patients using standard Heart Disease

# %%
# Install if the module doesn't exist
! pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in /usr/local/lib/python3.7/dist-packages (0.1.9)

# %% [markdown]
# ###### Importing Heart Disease Data Set and Customizing

# %%
import pandas as pd
from urllib.request import urlopen

#data_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
data_url = 'https://tinyurl.com/processed-hungarian-data'


#names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']

names = urlopen('https://tinyurl.com/names-csv').read().decode().split(',')   # need a live connection

data = urlopen(data_url)
heart_disease = pd.read_csv(data, names = names)                              # gets Cleveland data

heart_disease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %% [markdown]
# ###### Dropping columns which are more non numeric

# %%
heart_disease.drop(['ca', 'slope', 'thal', 'oldpeak'], axis=1)

# also replacing '?' with numpy's NaN ( not a number)

import numpy

heart_disease = heart_disease.replace('?', numpy.NaN)

# %% [markdown]
# ### Modeling Heart Disease Data
# <img src ="heart.png">

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

associations_list =  [
                       ('age', 'trestbps'),       ('age', 'fbs'),             ('sex', 'trestbps'),  
                       ('exang', 'trestbps'),     ('trestbps','heartdisease'),('fbs','heartdisease'),
                       ('heartdisease','restecg'),('heartdisease','thalach'), ('heartdisease','chol')
                    ]
model = BayesianModel(associations_list)

# Learing CPDs using Maximum Likelihood Estimators
model.fit(heart_disease, estimator=MaximumLikelihoodEstimator)

# %%
print(model.get_cpds('age'))
# Out:
# +---------+---+
# | age(28) | 0 |
# +---------+---+
# | age(29) | 0 |
# +---------+---+
# | age(30) | 0 |
# +---------+---+
# | age(31) | 0 |
# +---------+---+
# | age(32) | 0 |
# +---------+---+
# | age(33) | 0 |
# +---------+---+
# | age(34) | 0 |
# +---------+---+
# | age(35) | 0 |
# +---------+---+
# | age(36) | 0 |
# +---------+---+
# | age(37) | 0 |
# +---------+---+
# | age(38) | 0 |
# +---------+---+
# | age(39) | 0 |
# +---------+---+
# | age(40) | 0 |
# +---------+---+
# | age(41) | 0 |
# +---------+---+
# | age(42) | 0 |
# +---------+---+
# | age(43) | 0 |
# +---------+---+
# | age(44) | 0 |
# +---------+---+
# | age(45) | 0 |
# +---------+---+
# | age(46) | 0 |
# +---------+---+
# | age(47) | 1 |
# +---------+---+
# | age(48) | 0 |
# +---------+---+
# | age(49) | 0 |
# +---------+---+
# | age(50) | 0 |
# +---------+---+
# | age(51) | 0 |
# +---------+---+
# | age(52) | 0 |
# +---------+---+
# | age(53) | 0 |
# +---------+---+
# | age(54) | 0 |
# +---------+---+
# | age(55) | 0 |
# +---------+---+
# | age(56) | 0 |
# +---------+---+
# | age(57) | 0 |
# +---------+---+
# | age(58) | 0 |
# +---------+---+
# | age(59) | 0 |
# +---------+---+
# | age(60) | 0 |
# +---------+---+
# | age(61) | 0 |
# +---------+---+
# | age(62) | 0 |
# +---------+---+
# | age(63) | 0 |
# +---------+---+
# | age(65) | 0 |
# +---------+---+
# | age(66) | 0 |
# +---------+---+

# %%
print(model.get_cpds('sex'))
# Out:
# +--------+---+
# | sex(0) | 0 |
# +--------+---+
# | sex(1) | 1 |
# +--------+---+

# %%
model.get_independencies()
# Out:
# (age _|_ sex, exang)
# (age _|_ exang | sex)
# (age _|_ sex | exang)
# (age _|_ thalach, chol, restecg | heartdisease)
# (age _|_ sex, exang | fbs)
# (age _|_ restecg, thalach | heartdisease, chol)
# (age _|_ restecg, chol, thalach | sex, heartdisease)
# (age _|_ exang | sex, fbs)
# (age _|_ chol, restecg | heartdisease, thalach)
# (age _|_ restecg, chol, thalach | heartdisease, exang)
# (age _|_ sex | exang, fbs)
# (age _|_ chol, thalach | heartdisease, restecg)
# (age _|_ restecg, chol, thalach | heartdisease, trestbps)
# (age _|_ restecg, chol, thalach | heartdisease, fbs)
# (age _|_ heartdisease, chol, restecg, thalach | trestbps, fbs)
# (age _|_ restecg, thalach | sex, heartdisease, chol)
# (age _|_ restecg | heartdisease, chol, thalach)
# (age _|_ restecg, thalach | heartdisease, chol, exang)
# (age _|_ thalach | heartdisease, chol, restecg)
# (age _|_ restecg, thalach | heartdisease, chol, trestbps)
# (age _|_ restecg, thalach | heartdisease, chol, fbs)
# (age _|_ heartdisease, restecg, thalach | chol, trestbps, fbs)
# (age _|_ chol, restecg | sex, heartdisease, thalach)
# (age _|_ restecg, chol, thalach | sex, heartdisease, exang)
# (age _|_ chol, thalach | sex, heartdisease, restecg)
# (age _|_ restecg, chol, thalach | sex, heartdisease, trestbps)
# (age _|_ restecg, chol, thalach | sex, heartdisease, fbs)
# (age _|_ heartdisease, restecg, chol, thalach | sex, trestbps, fbs)
# (age _|_ chol, restecg | heartdisease, thalach, exang)
# (age _|_ chol | heartdisease, restecg, thalach)
# (age _|_ chol, restecg | heartdisease, thalach, trestbps)
# (age _|_ chol, restecg | heartdisease, thalach, fbs)
# (age _|_ heartdisease, chol, restecg | thalach, trestbps, fbs)
# (age _|_ chol, thalach | heartdisease, restecg, exang)
# (age _|_ restecg, chol, thalach | heartdisease, trestbps, exang)
# (age _|_ restecg, chol, thalach | heartdisease, exang, fbs)
# (age _|_ heartdisease, restecg, chol, thalach | trestbps, exang, fbs)
# (age _|_ chol, thalach | heartdisease, restecg, trestbps)
# (age _|_ chol, thalach | heartdisease, restecg, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, trestbps, fbs)
# (age _|_ heartdisease, chol, thalach | restecg, trestbps, fbs)
# (age _|_ restecg | sex, heartdisease, chol, thalach)
# (age _|_ thalach, restecg | sex, heartdisease, chol, exang)
# (age _|_ thalach | sex, heartdisease, chol, restecg)
# (age _|_ thalach, restecg | sex, heartdisease, chol, trestbps)
# (age _|_ thalach, restecg | sex, heartdisease, chol, fbs)
# (age _|_ heartdisease, restecg, thalach | sex, chol, trestbps, fbs)
# (age _|_ restecg | heartdisease, chol, thalach, exang)
# (age _|_ restecg | heartdisease, chol, thalach, trestbps)
# (age _|_ restecg | heartdisease, chol, thalach, fbs)
# (age _|_ heartdisease, restecg | chol, thalach, trestbps, fbs)
# (age _|_ thalach | heartdisease, chol, restecg, exang)
# (age _|_ thalach, restecg | heartdisease, chol, trestbps, exang)
# (age _|_ thalach, restecg | heartdisease, chol, exang, fbs)
# (age _|_ heartdisease, restecg, thalach | chol, trestbps, exang, fbs)
# (age _|_ thalach | heartdisease, chol, restecg, trestbps)
# (age _|_ thalach | heartdisease, chol, restecg, fbs)
# (age _|_ thalach, restecg | heartdisease, chol, trestbps, fbs)
# (age _|_ heartdisease, thalach | chol, restecg, trestbps, fbs)
# (age _|_ chol, restecg | sex, heartdisease, thalach, exang)
# (age _|_ chol | sex, heartdisease, restecg, thalach)
# (age _|_ chol, restecg | sex, heartdisease, thalach, trestbps)
# (age _|_ chol, restecg | sex, heartdisease, thalach, fbs)
# (age _|_ heartdisease, chol, restecg | sex, thalach, trestbps, fbs)
# (age _|_ chol, thalach | sex, heartdisease, restecg, exang)
# (age _|_ thalach, chol, restecg | sex, heartdisease, trestbps, exang)
# (age _|_ thalach, chol, restecg | sex, heartdisease, exang, fbs)
# (age _|_ heartdisease, chol, restecg, thalach | sex, trestbps, exang, fbs)
# (age _|_ chol, thalach | sex, heartdisease, restecg, trestbps)
# (age _|_ chol, thalach | sex, heartdisease, restecg, fbs)
# (age _|_ thalach, chol, restecg | sex, heartdisease, trestbps, fbs)
# (age _|_ heartdisease, chol, thalach | sex, restecg, trestbps, fbs)
# (age _|_ chol | heartdisease, restecg, thalach, exang)
# (age _|_ chol, restecg | heartdisease, thalach, trestbps, exang)
# (age _|_ chol, restecg | heartdisease, thalach, exang, fbs)
# (age _|_ heartdisease, chol, restecg | thalach, trestbps, exang, fbs)
# (age _|_ chol | heartdisease, restecg, thalach, trestbps)
# (age _|_ chol | heartdisease, restecg, thalach, fbs)
# (age _|_ chol, restecg | heartdisease, thalach, trestbps, fbs)
# (age _|_ heartdisease, chol | restecg, thalach, trestbps, fbs)
# (age _|_ chol, thalach | heartdisease, restecg, trestbps, exang)
# (age _|_ chol, thalach | heartdisease, restecg, exang, fbs)
# (age _|_ thalach, chol, restecg | heartdisease, trestbps, exang, fbs)
# (age _|_ heartdisease, chol, thalach | restecg, trestbps, exang, fbs)
# (age _|_ chol, thalach | heartdisease, restecg, trestbps, fbs)
# (age _|_ restecg | chol, sex, exang, heartdisease, thalach)
# (age _|_ restecg | chol, sex, heartdisease, thalach, trestbps)
# (age _|_ restecg | chol, sex, heartdisease, thalach, fbs)
# (age _|_ heartdisease, restecg | chol, sex, thalach, trestbps, fbs)
# (age _|_ thalach | chol, sex, exang, heartdisease, restecg)
# (age _|_ thalach, restecg | chol, sex, exang, heartdisease, trestbps)
# (age _|_ thalach, restecg | chol, sex, exang, heartdisease, fbs)
# (age _|_ heartdisease, restecg, thalach | chol, sex, exang, trestbps, fbs)
# (age _|_ thalach | chol, sex, heartdisease, restecg, trestbps)
# (age _|_ thalach | chol, sex, heartdisease, restecg, fbs)
# (age _|_ thalach, restecg | chol, sex, heartdisease, trestbps, fbs)
# (age _|_ heartdisease, thalach | chol, sex, restecg, trestbps, fbs)
# (age _|_ restecg | chol, exang, heartdisease, thalach, trestbps)
# (age _|_ restecg | chol, exang, heartdisease, thalach, fbs)
# (age _|_ heartdisease, restecg | chol, exang, thalach, trestbps, fbs)
# (age _|_ restecg | chol, heartdisease, thalach, trestbps, fbs)
# (age _|_ heartdisease | chol, thalach, restecg, trestbps, fbs)
# (age _|_ thalach | chol, exang, heartdisease, restecg, trestbps)
# (age _|_ thalach | chol, exang, heartdisease, restecg, fbs)
# (age _|_ thalach, restecg | chol, exang, heartdisease, trestbps, fbs)
# (age _|_ heartdisease, thalach | chol, exang, restecg, trestbps, fbs)
# (age _|_ thalach | chol, heartdisease, restecg, trestbps, fbs)
# (age _|_ chol | sex, thalach, exang, heartdisease, restecg)
# (age _|_ chol, restecg | sex, exang, heartdisease, thalach, trestbps)
# (age _|_ chol, restecg | sex, exang, heartdisease, thalach, fbs)
# (age _|_ heartdisease, chol, restecg | sex, exang, thalach, trestbps, fbs)
# (age _|_ chol | sex, thalach, heartdisease, restecg, trestbps)
# (age _|_ chol | sex, thalach, heartdisease, restecg, fbs)
# (age _|_ chol, restecg | sex, heartdisease, thalach, trestbps, fbs)
# (age _|_ heartdisease, chol | sex, thalach, restecg, trestbps, fbs)
# (age _|_ chol, thalach | sex, exang, heartdisease, restecg, trestbps)
# (age _|_ chol, thalach | sex, exang, heartdisease, restecg, fbs)
# (age _|_ thalach, chol, restecg | sex, exang, heartdisease, trestbps, fbs)
# (age _|_ heartdisease, chol, thalach | sex, exang, restecg, trestbps, fbs)
# (age _|_ chol, thalach | sex, heartdisease, restecg, trestbps, fbs)
# (age _|_ chol | thalach, exang, heartdisease, restecg, trestbps)
# (age _|_ chol | thalach, exang, heartdisease, restecg, fbs)
# (age _|_ chol, restecg | exang, heartdisease, thalach, trestbps, fbs)
# (age _|_ heartdisease, chol | thalach, exang, restecg, trestbps, fbs)
# (age _|_ chol | thalach, heartdisease, restecg, trestbps, fbs)
# (age _|_ chol, thalach | exang, heartdisease, restecg, trestbps, fbs)
# (age _|_ restecg | chol, sex, exang, heartdisease, thalach, trestbps)
# (age _|_ restecg | chol, sex, exang, heartdisease, thalach, fbs)
# (age _|_ heartdisease, restecg | chol, sex, exang, thalach, trestbps, fbs)
# (age _|_ restecg | chol, sex, heartdisease, thalach, trestbps, fbs)
# (age _|_ heartdisease | chol, sex, thalach, restecg, trestbps, fbs)
# (age _|_ thalach | chol, sex, exang, heartdisease, restecg, trestbps)
# (age _|_ thalach | chol, sex, exang, heartdisease, restecg, fbs)
# (age _|_ thalach, restecg | chol, sex, exang, heartdisease, trestbps, fbs)
# (age _|_ heartdisease, thalach | chol, sex, exang, restecg, trestbps, fbs)
# (age _|_ thalach | chol, sex, heartdisease, restecg, trestbps, fbs)
# (age _|_ restecg | chol, exang, heartdisease, thalach, trestbps, fbs)
# (age _|_ heartdisease | chol, thalach, exang, restecg, trestbps, fbs)
# (age _|_ thalach | chol, exang, heartdisease, restecg, trestbps, fbs)
# (age _|_ chol | sex, thalach, exang, heartdisease, restecg, trestbps)
# (age _|_ chol | sex, thalach, exang, heartdisease, restecg, fbs)
# (age _|_ chol, restecg | sex, exang, heartdisease, thalach, trestbps, fbs)
# (age _|_ heartdisease, chol | sex, thalach, exang, restecg, trestbps, fbs)
# (age _|_ chol | sex, thalach, heartdisease, restecg, trestbps, fbs)
# (age _|_ chol, thalach | sex, exang, heartdisease, restecg, trestbps, fbs)
# (age _|_ chol | thalach, exang, heartdisease, restecg, trestbps, fbs)
# (age _|_ restecg | chol, sex, exang, heartdisease, thalach, trestbps, fbs)
# (age _|_ heartdisease | chol, sex, thalach, exang, restecg, trestbps, fbs)
# (age _|_ thalach | chol, sex, exang, heartdisease, restecg, trestbps, fbs)
# (age _|_ chol | sex, thalach, exang, heartdisease, restecg, trestbps, fbs)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, chol, restecg | heartdisease)
# (trestbps _|_ thalach, restecg | heartdisease, chol)
# (trestbps _|_ fbs | sex, age)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease)
# (trestbps _|_ chol, restecg | heartdisease, thalach)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, exang)
# (trestbps _|_ chol, thalach | heartdisease, restecg)
# (trestbps _|_ thalach, chol, restecg | heartdisease, fbs)
# (trestbps _|_ thalach, restecg | sex, heartdisease, chol)
# (trestbps _|_ restecg | heartdisease, chol, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, age, chol)
# (trestbps _|_ thalach, restecg | heartdisease, chol, exang)
# (trestbps _|_ thalach | heartdisease, chol, restecg)
# (trestbps _|_ thalach, restecg | heartdisease, chol, fbs)
# (trestbps _|_ chol, restecg | sex, heartdisease, thalach)
# (trestbps _|_ fbs | sex, age, exang)
# (trestbps _|_ restecg, chol, thalach | sex, heartdisease, age)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease, exang)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease, fbs)
# (trestbps _|_ chol, restecg | heartdisease, age, thalach)
# (trestbps _|_ chol, restecg | heartdisease, thalach, exang)
# (trestbps _|_ chol | heartdisease, restecg, thalach)
# (trestbps _|_ chol, restecg | heartdisease, thalach, fbs)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, exang)
# (trestbps _|_ chol, thalach | heartdisease, age, restecg)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, fbs)
# (trestbps _|_ chol, thalach | heartdisease, restecg, exang)
# (trestbps _|_ thalach, chol, restecg | heartdisease, exang, fbs)
# (trestbps _|_ chol, thalach | heartdisease, restecg, fbs)
# (trestbps _|_ restecg | sex, heartdisease, chol, thalach)
# (trestbps _|_ thalach, restecg | sex, heartdisease, age, chol)
# (trestbps _|_ restecg, thalach | sex, heartdisease, chol, exang)
# (trestbps _|_ thalach | sex, heartdisease, chol, restecg)
# (trestbps _|_ restecg, thalach | sex, heartdisease, chol, fbs)
# (trestbps _|_ restecg | heartdisease, age, chol, thalach)
# (trestbps _|_ restecg | heartdisease, chol, thalach, exang)
# (trestbps _|_ restecg | heartdisease, chol, thalach, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, age, chol, exang)
# (trestbps _|_ thalach | heartdisease, age, chol, restecg)
# (trestbps _|_ thalach, restecg | heartdisease, age, chol, fbs)
# (trestbps _|_ thalach | heartdisease, chol, restecg, exang)
# (trestbps _|_ restecg, thalach | heartdisease, chol, exang, fbs)
# (trestbps _|_ thalach | heartdisease, chol, restecg, fbs)
# (trestbps _|_ chol, restecg | sex, heartdisease, age, thalach)
# (trestbps _|_ chol, restecg | sex, heartdisease, thalach, exang)
# (trestbps _|_ chol | sex, heartdisease, restecg, thalach)
# (trestbps _|_ chol, restecg | sex, heartdisease, thalach, fbs)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease, age, exang)
# (trestbps _|_ chol, thalach | sex, heartdisease, age, restecg)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease, age, fbs)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg, exang)
# (trestbps _|_ restecg, chol, thalach | sex, heartdisease, exang, fbs)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg, fbs)
# (trestbps _|_ chol, restecg | heartdisease, age, thalach, exang)
# (trestbps _|_ chol | heartdisease, age, thalach, restecg)
# (trestbps _|_ chol, restecg | heartdisease, age, thalach, fbs)
# (trestbps _|_ chol | heartdisease, restecg, thalach, exang)
# (trestbps _|_ chol, restecg | heartdisease, thalach, exang, fbs)
# (trestbps _|_ chol | heartdisease, restecg, thalach, fbs)
# (trestbps _|_ chol, thalach | heartdisease, age, restecg, exang)
# (trestbps _|_ thalach, chol, restecg | heartdisease, age, exang, fbs)
# (trestbps _|_ chol, thalach | heartdisease, age, restecg, fbs)
# (trestbps _|_ chol, thalach | heartdisease, restecg, exang, fbs)
# (trestbps _|_ restecg | chol, sex, age, heartdisease, thalach)
# (trestbps _|_ restecg | chol, sex, exang, heartdisease, thalach)
# (trestbps _|_ restecg | chol, sex, heartdisease, thalach, fbs)
# (trestbps _|_ thalach, restecg | chol, sex, age, exang, heartdisease)
# (trestbps _|_ thalach | chol, sex, age, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | chol, sex, age, heartdisease, fbs)
# (trestbps _|_ thalach | chol, sex, exang, heartdisease, restecg)
# (trestbps _|_ restecg, thalach | chol, sex, exang, heartdisease, fbs)
# (trestbps _|_ thalach | chol, sex, heartdisease, restecg, fbs)
# (trestbps _|_ restecg | chol, age, exang, heartdisease, thalach)
# (trestbps _|_ restecg | chol, age, heartdisease, thalach, fbs)
# (trestbps _|_ restecg | chol, exang, heartdisease, thalach, fbs)
# (trestbps _|_ thalach | chol, age, exang, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | chol, age, exang, heartdisease, fbs)
# (trestbps _|_ thalach | chol, age, heartdisease, restecg, fbs)
# (trestbps _|_ thalach | chol, exang, heartdisease, restecg, fbs)
# (trestbps _|_ chol, restecg | sex, age, exang, heartdisease, thalach)
# (trestbps _|_ chol | restecg, sex, age, heartdisease, thalach)
# (trestbps _|_ chol, restecg | sex, age, heartdisease, thalach, fbs)
# (trestbps _|_ chol | sex, thalach, exang, heartdisease, restecg)
# (trestbps _|_ chol, restecg | sex, exang, heartdisease, thalach, fbs)
# (trestbps _|_ chol | sex, thalach, heartdisease, restecg, fbs)
# (trestbps _|_ chol, thalach | sex, age, exang, heartdisease, restecg)
# (trestbps _|_ thalach, chol, restecg | sex, age, exang, heartdisease, fbs)
# (trestbps _|_ chol, thalach | sex, age, heartdisease, restecg, fbs)
# (trestbps _|_ chol, thalach | sex, exang, heartdisease, restecg, fbs)
# (trestbps _|_ chol | restecg, age, exang, heartdisease, thalach)
# (trestbps _|_ chol, restecg | age, exang, heartdisease, thalach, fbs)
# (trestbps _|_ chol | restecg, age, heartdisease, thalach, fbs)
# (trestbps _|_ chol | thalach, exang, heartdisease, restecg, fbs)
# (trestbps _|_ chol, thalach | age, exang, heartdisease, restecg, fbs)
# (trestbps _|_ restecg | chol, sex, age, exang, heartdisease, thalach)
# (trestbps _|_ restecg | chol, sex, age, heartdisease, thalach, fbs)
# (trestbps _|_ restecg | chol, sex, exang, heartdisease, thalach, fbs)
# (trestbps _|_ thalach | chol, sex, age, exang, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | chol, sex, age, exang, heartdisease, fbs)
# (trestbps _|_ thalach | chol, sex, age, heartdisease, restecg, fbs)
# (trestbps _|_ thalach | chol, sex, exang, heartdisease, restecg, fbs)
# (trestbps _|_ restecg | chol, age, exang, heartdisease, thalach, fbs)
# (trestbps _|_ thalach | chol, age, exang, heartdisease, restecg, fbs)
# (trestbps _|_ chol | restecg, sex, age, exang, heartdisease, thalach)
# (trestbps _|_ chol, restecg | sex, age, exang, heartdisease, thalach, fbs)
# (trestbps _|_ chol | restecg, sex, age, heartdisease, thalach, fbs)
# (trestbps _|_ chol | sex, thalach, exang, heartdisease, restecg, fbs)
# (trestbps _|_ chol, thalach | sex, age, exang, heartdisease, restecg, fbs)
# (trestbps _|_ chol | restecg, age, exang, heartdisease, thalach, fbs)
# (trestbps _|_ restecg | chol, sex, age, exang, heartdisease, thalach, fbs)
# (trestbps _|_ thalach | chol, sex, age, exang, heartdisease, restecg, fbs)
# (trestbps _|_ chol | restecg, sex, age, exang, heartdisease, thalach, fbs)
# (fbs _|_ sex, exang)
# (fbs _|_ exang | sex)
# (fbs _|_ sex, trestbps, exang | age)
# (fbs _|_ sex | exang)
# (fbs _|_ thalach, chol, restecg | heartdisease)
# (fbs _|_ thalach, restecg | heartdisease, chol)
# (fbs _|_ trestbps, exang | sex, age)
# (fbs _|_ thalach, chol, restecg | sex, heartdisease)
# (fbs _|_ chol, restecg | heartdisease, thalach)
# (fbs _|_ sex, trestbps | age, exang)
# (fbs _|_ restecg, chol, thalach | heartdisease, age)
# (fbs _|_ sex, exang | age, trestbps)
# (fbs _|_ thalach, chol, restecg | heartdisease, exang)
# (fbs _|_ chol, thalach | heartdisease, restecg)
# (fbs _|_ thalach, chol, restecg | heartdisease, trestbps)
# (fbs _|_ thalach, restecg | sex, heartdisease, chol)
# (fbs _|_ restecg | heartdisease, chol, thalach)
# (fbs _|_ restecg, thalach | heartdisease, age, chol)
# (fbs _|_ sex, exang | age, chol, trestbps)
# (fbs _|_ thalach, restecg | heartdisease, chol, exang)
# (fbs _|_ thalach | heartdisease, chol, restecg)
# (fbs _|_ thalach, restecg | heartdisease, chol, trestbps)
# (fbs _|_ chol, restecg | sex, heartdisease, thalach)
# (fbs _|_ trestbps | sex, age, exang)
# (fbs _|_ restecg, chol, thalach | sex, heartdisease, age)
# (fbs _|_ exang | sex, age, trestbps)
# (fbs _|_ thalach, chol, restecg | sex, heartdisease, exang)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg)
# (fbs _|_ thalach, chol, restecg | sex, heartdisease, trestbps)
# (fbs _|_ chol, restecg | heartdisease, age, thalach)
# (fbs _|_ sex, exang | age, thalach, trestbps)
# (fbs _|_ chol, restecg | heartdisease, thalach, exang)
# (fbs _|_ chol | heartdisease, restecg, thalach)
# (fbs _|_ chol, restecg | heartdisease, thalach, trestbps)
# (fbs _|_ restecg, chol, thalach | heartdisease, age, exang)
# (fbs _|_ sex | age, trestbps, exang)
# (fbs _|_ chol, thalach | heartdisease, age, restecg)
# (fbs _|_ sex, restecg, chol, exang, thalach | heartdisease, age, trestbps)
# (fbs _|_ sex, exang | age, restecg, trestbps)
# (fbs _|_ chol, thalach | heartdisease, restecg, exang)
# (fbs _|_ thalach, chol, restecg | heartdisease, trestbps, exang)
# (fbs _|_ chol, thalach | heartdisease, restecg, trestbps)
# (fbs _|_ restecg | sex, heartdisease, chol, thalach)
# (fbs _|_ thalach, restecg | sex, heartdisease, age, chol)
# (fbs _|_ exang | sex, age, chol, trestbps)
# (fbs _|_ restecg, thalach | sex, heartdisease, chol, exang)
# (fbs _|_ thalach | sex, heartdisease, chol, restecg)
# (fbs _|_ restecg, thalach | sex, heartdisease, chol, trestbps)
# (fbs _|_ restecg | heartdisease, age, chol, thalach)
# (fbs _|_ sex, exang | age, chol, thalach, trestbps)
# (fbs _|_ restecg | heartdisease, chol, thalach, exang)
# (fbs _|_ restecg | heartdisease, chol, thalach, trestbps)
# (fbs _|_ thalach, restecg | heartdisease, age, chol, exang)
# (fbs _|_ sex | age, chol, trestbps, exang)
# (fbs _|_ thalach | heartdisease, age, chol, restecg)
# (fbs _|_ sex, thalach, restecg, exang | heartdisease, age, chol, trestbps)
# (fbs _|_ sex, exang | age, chol, restecg, trestbps)
# (fbs _|_ thalach | heartdisease, chol, restecg, exang)
# (fbs _|_ restecg, thalach | heartdisease, chol, trestbps, exang)
# (fbs _|_ thalach | heartdisease, chol, restecg, trestbps)
# (fbs _|_ chol, restecg | sex, heartdisease, age, thalach)
# (fbs _|_ exang | sex, age, thalach, trestbps)
# (fbs _|_ chol, restecg | sex, heartdisease, thalach, exang)
# (fbs _|_ chol | sex, heartdisease, restecg, thalach)
# (fbs _|_ chol, restecg | sex, heartdisease, thalach, trestbps)
# (fbs _|_ thalach, chol, restecg | sex, heartdisease, age, exang)
# (fbs _|_ chol, thalach | sex, heartdisease, age, restecg)
# (fbs _|_ thalach, chol, restecg, exang | sex, heartdisease, age, trestbps)
# (fbs _|_ exang | sex, age, restecg, trestbps)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg, exang)
# (fbs _|_ restecg, chol, thalach | sex, heartdisease, trestbps, exang)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg, trestbps)
# (fbs _|_ chol, restecg | heartdisease, age, thalach, exang)
# (fbs _|_ sex | age, thalach, trestbps, exang)
# (fbs _|_ chol | heartdisease, age, thalach, restecg)
# (fbs _|_ sex, chol, restecg, exang | heartdisease, age, thalach, trestbps)
# (fbs _|_ sex, exang | age, thalach, trestbps, restecg)
# (fbs _|_ chol | heartdisease, restecg, thalach, exang)
# (fbs _|_ chol, restecg | heartdisease, thalach, trestbps, exang)
# (fbs _|_ chol | heartdisease, restecg, thalach, trestbps)
# (fbs _|_ chol, thalach | heartdisease, age, restecg, exang)
# (fbs _|_ sex, thalach, chol, restecg | heartdisease, age, trestbps, exang)
# (fbs _|_ sex | age, restecg, trestbps, exang)
# (fbs _|_ sex, chol, thalach, exang | heartdisease, age, restecg, trestbps)
# (fbs _|_ chol, thalach | heartdisease, restecg, trestbps, exang)
# (fbs _|_ restecg | chol, sex, age, heartdisease, thalach)
# (fbs _|_ exang | chol, sex, age, thalach, trestbps)
# (fbs _|_ restecg | chol, sex, exang, heartdisease, thalach)
# (fbs _|_ restecg | chol, sex, heartdisease, thalach, trestbps)
# (fbs _|_ thalach, restecg | chol, sex, age, exang, heartdisease)
# (fbs _|_ thalach | chol, sex, age, heartdisease, restecg)
# (fbs _|_ thalach, restecg, exang | chol, sex, age, heartdisease, trestbps)
# (fbs _|_ exang | chol, sex, age, restecg, trestbps)
# (fbs _|_ thalach | chol, sex, exang, heartdisease, restecg)
# (fbs _|_ restecg, thalach | chol, sex, exang, heartdisease, trestbps)
# (fbs _|_ thalach | chol, sex, heartdisease, restecg, trestbps)
# (fbs _|_ restecg | chol, age, exang, heartdisease, thalach)
# (fbs _|_ sex | chol, age, exang, thalach, trestbps)
# (fbs _|_ sex, restecg, exang | chol, age, heartdisease, thalach, trestbps)
# (fbs _|_ sex, exang | restecg, chol, age, thalach, trestbps)
# (fbs _|_ restecg | chol, exang, heartdisease, thalach, trestbps)
# (fbs _|_ thalach | chol, age, exang, heartdisease, restecg)
# (fbs _|_ sex, thalach, restecg | chol, age, exang, heartdisease, trestbps)
# (fbs _|_ sex | chol, age, exang, restecg, trestbps)
# (fbs _|_ sex, thalach, exang | chol, age, heartdisease, restecg, trestbps)
# (fbs _|_ thalach | chol, exang, heartdisease, restecg, trestbps)
# (fbs _|_ chol, restecg | sex, age, exang, heartdisease, thalach)
# (fbs _|_ chol | restecg, sex, age, heartdisease, thalach)
# (fbs _|_ chol, restecg, exang | sex, age, heartdisease, thalach, trestbps)
# (fbs _|_ exang | restecg, sex, age, thalach, trestbps)
# (fbs _|_ chol | sex, thalach, exang, heartdisease, restecg)
# (fbs _|_ chol, restecg | sex, exang, heartdisease, thalach, trestbps)
# (fbs _|_ chol | sex, thalach, heartdisease, restecg, trestbps)
# (fbs _|_ chol, thalach | sex, age, exang, heartdisease, restecg)
# (fbs _|_ thalach, chol, restecg | sex, age, exang, heartdisease, trestbps)
# (fbs _|_ chol, thalach, exang | sex, age, heartdisease, restecg, trestbps)
# (fbs _|_ chol, thalach | sex, exang, heartdisease, restecg, trestbps)
# (fbs _|_ chol | restecg, age, exang, heartdisease, thalach)
# (fbs _|_ sex, chol, restecg | age, exang, heartdisease, thalach, trestbps)
# (fbs _|_ sex | restecg, age, exang, thalach, trestbps)
# (fbs _|_ sex, chol, exang | restecg, age, heartdisease, thalach, trestbps)
# (fbs _|_ chol | thalach, exang, heartdisease, restecg, trestbps)
# (fbs _|_ sex, chol, thalach | age, exang, heartdisease, restecg, trestbps)
# (fbs _|_ restecg | chol, sex, age, exang, heartdisease, thalach)
# (fbs _|_ restecg, exang | chol, sex, age, heartdisease, thalach, trestbps)
# (fbs _|_ exang | restecg, chol, sex, age, thalach, trestbps)
# (fbs _|_ restecg | chol, sex, exang, heartdisease, thalach, trestbps)
# (fbs _|_ thalach | chol, sex, age, exang, heartdisease, restecg)
# (fbs _|_ thalach, restecg | chol, sex, age, exang, heartdisease, trestbps)
# (fbs _|_ thalach, exang | chol, sex, age, heartdisease, restecg, trestbps)
# (fbs _|_ thalach | chol, sex, exang, heartdisease, restecg, trestbps)
# (fbs _|_ sex, restecg | chol, age, exang, heartdisease, thalach, trestbps)
# (fbs _|_ sex | restecg, chol, age, exang, thalach, trestbps)
# (fbs _|_ sex, exang | restecg, chol, age, heartdisease, thalach, trestbps)
# (fbs _|_ sex, thalach | chol, age, exang, heartdisease, restecg, trestbps)
# (fbs _|_ chol | restecg, sex, age, exang, heartdisease, thalach)
# (fbs _|_ chol, restecg | sex, age, exang, heartdisease, thalach, trestbps)
# (fbs _|_ chol, exang | restecg, sex, age, heartdisease, thalach, trestbps)
# (fbs _|_ chol | sex, thalach, exang, heartdisease, restecg, trestbps)
# (fbs _|_ chol, thalach | sex, age, exang, heartdisease, restecg, trestbps)
# (fbs _|_ sex, chol | restecg, age, exang, heartdisease, thalach, trestbps)
# (fbs _|_ restecg | chol, sex, age, exang, heartdisease, thalach, trestbps)
# (fbs _|_ exang | restecg, chol, sex, age, heartdisease, thalach, trestbps)
# (fbs _|_ thalach | chol, sex, age, exang, heartdisease, restecg, trestbps)
# (fbs _|_ sex | restecg, chol, age, exang, heartdisease, thalach, trestbps)
# (fbs _|_ chol | restecg, sex, age, exang, heartdisease, thalach, trestbps)
# (sex _|_ age, exang, fbs)
# (sex _|_ exang, fbs | age)
# (sex _|_ age, fbs | exang)
# (sex _|_ thalach, chol, restecg | heartdisease)
# (sex _|_ age, exang | fbs)
# (sex _|_ thalach, restecg | heartdisease, chol)
# (sex _|_ chol, restecg | heartdisease, thalach)
# (sex _|_ fbs | age, exang)
# (sex _|_ restecg, chol, thalach | heartdisease, age)
# (sex _|_ restecg, chol, heartdisease, thalach, fbs | age, trestbps)
# (sex _|_ exang | age, fbs)
# (sex _|_ thalach, chol, restecg | heartdisease, exang)
# (sex _|_ age | exang, fbs)
# (sex _|_ chol, thalach | heartdisease, restecg)
# (sex _|_ thalach, chol, restecg | heartdisease, trestbps)
# (sex _|_ thalach, chol, restecg | heartdisease, fbs)
# (sex _|_ heartdisease, chol, restecg, thalach | trestbps, fbs)
# (sex _|_ restecg | heartdisease, chol, thalach)
# (sex _|_ restecg, thalach | heartdisease, age, chol)
# (sex _|_ heartdisease, restecg, thalach, fbs | age, chol, trestbps)
# (sex _|_ thalach, restecg | heartdisease, chol, exang)
# (sex _|_ thalach | heartdisease, chol, restecg)
# (sex _|_ thalach, restecg | heartdisease, chol, trestbps)
# (sex _|_ thalach, restecg | heartdisease, chol, fbs)
# (sex _|_ heartdisease, restecg, thalach | chol, trestbps, fbs)
# (sex _|_ chol, restecg | heartdisease, age, thalach)
# (sex _|_ heartdisease, chol, restecg, fbs | age, thalach, trestbps)
# (sex _|_ chol, restecg | heartdisease, thalach, exang)
# (sex _|_ chol | heartdisease, restecg, thalach)
# (sex _|_ chol, restecg | heartdisease, thalach, trestbps)
# (sex _|_ chol, restecg | heartdisease, thalach, fbs)
# (sex _|_ heartdisease, chol, restecg | thalach, trestbps, fbs)
# (sex _|_ restecg, chol, thalach | heartdisease, age, exang)
# (sex _|_ restecg, chol, heartdisease, thalach, fbs | age, trestbps, exang)
# (sex _|_ chol, thalach | heartdisease, age, restecg)
# (sex _|_ restecg, chol, thalach, fbs | heartdisease, age, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, age, fbs)
# (sex _|_ heartdisease, chol, thalach, fbs | age, restecg, trestbps)
# (sex _|_ heartdisease, restecg, chol, thalach | age, trestbps, fbs)
# (sex _|_ chol, thalach | heartdisease, restecg, exang)
# (sex _|_ thalach, chol, restecg | heartdisease, trestbps, exang)
# (sex _|_ thalach, chol, restecg | heartdisease, exang, fbs)
# (sex _|_ heartdisease, chol, restecg, thalach | trestbps, exang, fbs)
# (sex _|_ chol, thalach | heartdisease, restecg, trestbps)
# (sex _|_ chol, thalach | heartdisease, restecg, fbs)
# (sex _|_ thalach, chol, restecg | heartdisease, trestbps, fbs)
# (sex _|_ heartdisease, chol, thalach | restecg, trestbps, fbs)
# (sex _|_ restecg | heartdisease, age, chol, thalach)
# (sex _|_ heartdisease, restecg, fbs | age, chol, thalach, trestbps)
# (sex _|_ restecg | heartdisease, chol, thalach, exang)
# (sex _|_ restecg | heartdisease, chol, thalach, trestbps)
# (sex _|_ restecg | heartdisease, chol, thalach, fbs)
# (sex _|_ heartdisease, restecg | chol, thalach, trestbps, fbs)
# (sex _|_ thalach, restecg | heartdisease, age, chol, exang)
# (sex _|_ heartdisease, restecg, thalach, fbs | age, chol, trestbps, exang)
# (sex _|_ thalach | heartdisease, age, chol, restecg)
# (sex _|_ thalach, restecg, fbs | heartdisease, age, chol, trestbps)
# (sex _|_ thalach, restecg | heartdisease, age, chol, fbs)
# (sex _|_ heartdisease, thalach, fbs | age, chol, restecg, trestbps)
# (sex _|_ heartdisease, restecg, thalach | age, chol, trestbps, fbs)
# (sex _|_ thalach | heartdisease, chol, restecg, exang)
# (sex _|_ restecg, thalach | heartdisease, chol, trestbps, exang)
# (sex _|_ restecg, thalach | heartdisease, chol, exang, fbs)
# (sex _|_ heartdisease, restecg, thalach | chol, trestbps, exang, fbs)
# (sex _|_ thalach | heartdisease, chol, restecg, trestbps)
# (sex _|_ thalach | heartdisease, chol, restecg, fbs)
# (sex _|_ restecg, thalach | heartdisease, chol, trestbps, fbs)
# (sex _|_ heartdisease, thalach | chol, restecg, trestbps, fbs)
# (sex _|_ chol, restecg | heartdisease, age, thalach, exang)
# (sex _|_ heartdisease, chol, restecg, fbs | age, thalach, trestbps, exang)
# (sex _|_ chol | heartdisease, age, thalach, restecg)
# (sex _|_ chol, restecg, fbs | heartdisease, age, thalach, trestbps)
# (sex _|_ chol, restecg | heartdisease, age, thalach, fbs)
# (sex _|_ heartdisease, chol, fbs | age, thalach, trestbps, restecg)
# (sex _|_ heartdisease, chol, restecg | age, thalach, trestbps, fbs)
# (sex _|_ chol | heartdisease, restecg, thalach, exang)
# (sex _|_ chol, restecg | heartdisease, thalach, trestbps, exang)
# (sex _|_ chol, restecg | heartdisease, thalach, exang, fbs)
# (sex _|_ heartdisease, chol, restecg | thalach, trestbps, exang, fbs)
# (sex _|_ chol | heartdisease, restecg, thalach, trestbps)
# (sex _|_ chol | heartdisease, restecg, thalach, fbs)
# (sex _|_ chol, restecg | heartdisease, thalach, trestbps, fbs)
# (sex _|_ heartdisease, chol | restecg, thalach, trestbps, fbs)
# (sex _|_ chol, thalach | heartdisease, age, restecg, exang)
# (sex _|_ thalach, chol, restecg, fbs | heartdisease, age, trestbps, exang)
# (sex _|_ thalach, chol, restecg | heartdisease, age, exang, fbs)
# (sex _|_ heartdisease, chol, thalach, fbs | age, restecg, trestbps, exang)
# (sex _|_ heartdisease, chol, restecg, thalach | age, trestbps, exang, fbs)
# (sex _|_ chol, thalach, fbs | heartdisease, age, restecg, trestbps)
# (sex _|_ chol, thalach | heartdisease, age, restecg, fbs)
# (sex _|_ thalach, chol, restecg | heartdisease, age, trestbps, fbs)
# (sex _|_ heartdisease, chol, thalach | age, restecg, trestbps, fbs)
# (sex _|_ chol, thalach | heartdisease, restecg, trestbps, exang)
# (sex _|_ chol, thalach | heartdisease, restecg, exang, fbs)
# (sex _|_ restecg, chol, thalach | heartdisease, trestbps, exang, fbs)
# (sex _|_ heartdisease, chol, thalach | restecg, trestbps, exang, fbs)
# (sex _|_ chol, thalach | heartdisease, restecg, trestbps, fbs)
# (sex _|_ restecg | chol, age, exang, heartdisease, thalach)
# (sex _|_ heartdisease, restecg, fbs | chol, age, exang, thalach, trestbps)
# (sex _|_ restecg, fbs | chol, age, heartdisease, thalach, trestbps)
# (sex _|_ restecg | chol, age, heartdisease, thalach, fbs)
# (sex _|_ heartdisease, fbs | restecg, chol, age, thalach, trestbps)
# (sex _|_ heartdisease, restecg | chol, age, thalach, trestbps, fbs)
# (sex _|_ restecg | chol, exang, heartdisease, thalach, trestbps)
# (sex _|_ restecg | chol, exang, heartdisease, thalach, fbs)
# (sex _|_ heartdisease, restecg | chol, exang, thalach, trestbps, fbs)
# (sex _|_ restecg | chol, heartdisease, thalach, trestbps, fbs)
# (sex _|_ heartdisease | chol, thalach, restecg, trestbps, fbs)
# (sex _|_ thalach | chol, age, exang, heartdisease, restecg)
# (sex _|_ thalach, restecg, fbs | chol, age, exang, heartdisease, trestbps)
# (sex _|_ thalach, restecg | chol, age, exang, heartdisease, fbs)
# (sex _|_ heartdisease, thalach, fbs | chol, age, exang, restecg, trestbps)
# (sex _|_ heartdisease, restecg, thalach | chol, age, exang, trestbps, fbs)
# (sex _|_ thalach, fbs | chol, age, heartdisease, restecg, trestbps)
# (sex _|_ thalach | chol, age, heartdisease, restecg, fbs)
# (sex _|_ thalach, restecg | chol, age, heartdisease, trestbps, fbs)
# (sex _|_ heartdisease, thalach | chol, age, restecg, trestbps, fbs)
# (sex _|_ thalach | chol, exang, heartdisease, restecg, trestbps)
# (sex _|_ thalach | chol, exang, heartdisease, restecg, fbs)
# (sex _|_ restecg, thalach | chol, exang, heartdisease, trestbps, fbs)
# (sex _|_ heartdisease, thalach | chol, exang, restecg, trestbps, fbs)
# (sex _|_ thalach | chol, heartdisease, restecg, trestbps, fbs)
# (sex _|_ chol | restecg, age, exang, heartdisease, thalach)
# (sex _|_ chol, restecg, fbs | age, exang, heartdisease, thalach, trestbps)
# (sex _|_ chol, restecg | age, exang, heartdisease, thalach, fbs)
# (sex _|_ heartdisease, chol, fbs | restecg, age, exang, thalach, trestbps)
# (sex _|_ heartdisease, chol, restecg | age, exang, thalach, trestbps, fbs)
# (sex _|_ chol, fbs | restecg, age, heartdisease, thalach, trestbps)
# (sex _|_ chol | restecg, age, heartdisease, thalach, fbs)
# (sex _|_ chol, restecg | age, heartdisease, thalach, trestbps, fbs)
# (sex _|_ heartdisease, chol | restecg, age, thalach, trestbps, fbs)
# (sex _|_ chol | thalach, exang, heartdisease, restecg, trestbps)
# (sex _|_ chol | thalach, exang, heartdisease, restecg, fbs)
# (sex _|_ chol, restecg | exang, heartdisease, thalach, trestbps, fbs)
# (sex _|_ heartdisease, chol | thalach, exang, restecg, trestbps, fbs)
# (sex _|_ chol | thalach, heartdisease, restecg, trestbps, fbs)
# (sex _|_ chol, thalach, fbs | age, exang, heartdisease, restecg, trestbps)
# (sex _|_ chol, thalach | age, exang, heartdisease, restecg, fbs)
# (sex _|_ thalach, chol, restecg | age, exang, heartdisease, trestbps, fbs)
# (sex _|_ heartdisease, chol, thalach | age, exang, restecg, trestbps, fbs)
# (sex _|_ chol, thalach | age, heartdisease, restecg, trestbps, fbs)
# (sex _|_ chol, thalach | exang, heartdisease, restecg, trestbps, fbs)
# (sex _|_ restecg, fbs | chol, age, exang, heartdisease, thalach, trestbps)
# (sex _|_ restecg | chol, age, exang, heartdisease, thalach, fbs)
# (sex _|_ heartdisease, fbs | restecg, chol, age, exang, thalach, trestbps)
# (sex _|_ heartdisease, restecg | chol, age, exang, thalach, trestbps, fbs)
# (sex _|_ fbs | restecg, chol, age, heartdisease, thalach, trestbps)
# (sex _|_ restecg | chol, age, heartdisease, thalach, trestbps, fbs)
# (sex _|_ heartdisease | restecg, chol, age, thalach, trestbps, fbs)
# (sex _|_ restecg | chol, exang, heartdisease, thalach, trestbps, fbs)
# (sex _|_ heartdisease | chol, thalach, exang, restecg, trestbps, fbs)
# (sex _|_ thalach, fbs | chol, age, exang, heartdisease, restecg, trestbps)
# (sex _|_ thalach | chol, age, exang, heartdisease, restecg, fbs)
# (sex _|_ thalach, restecg | chol, age, exang, heartdisease, trestbps, fbs)
# (sex _|_ heartdisease, thalach | chol, age, exang, restecg, trestbps, fbs)
# (sex _|_ thalach | chol, age, heartdisease, restecg, trestbps, fbs)
# (sex _|_ thalach | chol, exang, heartdisease, restecg, trestbps, fbs)
# (sex _|_ chol, fbs | restecg, age, exang, heartdisease, thalach, trestbps)
# (sex _|_ chol | restecg, age, exang, heartdisease, thalach, fbs)
# (sex _|_ chol, restecg | age, exang, heartdisease, thalach, trestbps, fbs)
# (sex _|_ heartdisease, chol | restecg, age, exang, thalach, trestbps, fbs)
# (sex _|_ chol | restecg, age, heartdisease, thalach, trestbps, fbs)
# (sex _|_ chol | thalach, exang, heartdisease, restecg, trestbps, fbs)
# (sex _|_ chol, thalach | age, exang, heartdisease, restecg, trestbps, fbs)
# (sex _|_ fbs | restecg, chol, age, exang, heartdisease, thalach, trestbps)
# (sex _|_ restecg | chol, age, exang, heartdisease, thalach, trestbps, fbs)
# (sex _|_ heartdisease | restecg, chol, age, exang, thalach, trestbps, fbs)
# (sex _|_ thalach | chol, age, exang, heartdisease, restecg, trestbps, fbs)
# (sex _|_ chol | restecg, age, exang, heartdisease, thalach, trestbps, fbs)
# (exang _|_ sex, age, fbs)
# (exang _|_ age, fbs | sex)
# (exang _|_ sex, fbs | age)
# (exang _|_ thalach, chol, restecg | heartdisease)
# (exang _|_ sex, age | fbs)
# (exang _|_ thalach, restecg | heartdisease, chol)
# (exang _|_ fbs | sex, age)
# (exang _|_ thalach, chol, restecg | sex, heartdisease)
# (exang _|_ age | sex, fbs)
# (exang _|_ chol, restecg | heartdisease, thalach)
# (exang _|_ restecg, chol, thalach | heartdisease, age)
# (exang _|_ restecg, chol, heartdisease, thalach, fbs | age, trestbps)
# (exang _|_ sex | age, fbs)
# (exang _|_ chol, thalach | heartdisease, restecg)
# (exang _|_ thalach, chol, restecg | heartdisease, trestbps)
# (exang _|_ thalach, chol, restecg | heartdisease, fbs)
# (exang _|_ heartdisease, chol, restecg, thalach | trestbps, fbs)
# (exang _|_ thalach, restecg | sex, heartdisease, chol)
# (exang _|_ restecg | heartdisease, chol, thalach)
# (exang _|_ restecg, thalach | heartdisease, age, chol)
# (exang _|_ heartdisease, restecg, thalach, fbs | age, chol, trestbps)
# (exang _|_ thalach | heartdisease, chol, restecg)
# (exang _|_ thalach, restecg | heartdisease, chol, trestbps)
# (exang _|_ thalach, restecg | heartdisease, chol, fbs)
# (exang _|_ heartdisease, restecg, thalach | chol, trestbps, fbs)
# (exang _|_ chol, restecg | sex, heartdisease, thalach)
# (exang _|_ restecg, chol, thalach | sex, heartdisease, age)
# (exang _|_ restecg, chol, heartdisease, thalach, fbs | sex, age, trestbps)
# (exang _|_ chol, thalach | sex, heartdisease, restecg)
# (exang _|_ thalach, chol, restecg | sex, heartdisease, trestbps)
# (exang _|_ thalach, chol, restecg | sex, heartdisease, fbs)
# (exang _|_ heartdisease, chol, restecg, thalach | sex, trestbps, fbs)
# (exang _|_ chol, restecg | heartdisease, age, thalach)
# (exang _|_ heartdisease, chol, restecg, fbs | age, thalach, trestbps)
# (exang _|_ chol | heartdisease, restecg, thalach)
# (exang _|_ chol, restecg | heartdisease, thalach, trestbps)
# (exang _|_ chol, restecg | heartdisease, thalach, fbs)
# (exang _|_ heartdisease, chol, restecg | thalach, trestbps, fbs)
# (exang _|_ chol, thalach | heartdisease, age, restecg)
# (exang _|_ restecg, chol, thalach, fbs | heartdisease, age, trestbps)
# (exang _|_ restecg, chol, thalach | heartdisease, age, fbs)
# (exang _|_ heartdisease, chol, thalach, fbs | age, restecg, trestbps)
# (exang _|_ heartdisease, restecg, chol, thalach | age, trestbps, fbs)
# (exang _|_ chol, thalach | heartdisease, restecg, trestbps)
# (exang _|_ chol, thalach | heartdisease, restecg, fbs)
# (exang _|_ thalach, chol, restecg | heartdisease, trestbps, fbs)
# (exang _|_ heartdisease, chol, thalach | restecg, trestbps, fbs)
# (exang _|_ restecg | sex, heartdisease, chol, thalach)
# (exang _|_ thalach, restecg | sex, heartdisease, age, chol)
# (exang _|_ heartdisease, restecg, thalach, fbs | sex, age, chol, trestbps)
# (exang _|_ thalach | sex, heartdisease, chol, restecg)
# (exang _|_ restecg, thalach | sex, heartdisease, chol, trestbps)
# (exang _|_ restecg, thalach | sex, heartdisease, chol, fbs)
# (exang _|_ heartdisease, restecg, thalach | sex, chol, trestbps, fbs)
# (exang _|_ restecg | heartdisease, age, chol, thalach)
# (exang _|_ heartdisease, restecg, fbs | age, chol, thalach, trestbps)
# (exang _|_ restecg | heartdisease, chol, thalach, trestbps)
# (exang _|_ restecg | heartdisease, chol, thalach, fbs)
# (exang _|_ heartdisease, restecg | chol, thalach, trestbps, fbs)
# (exang _|_ thalach | heartdisease, age, chol, restecg)
# (exang _|_ thalach, restecg, fbs | heartdisease, age, chol, trestbps)
# (exang _|_ thalach, restecg | heartdisease, age, chol, fbs)
# (exang _|_ heartdisease, thalach, fbs | age, chol, restecg, trestbps)
# (exang _|_ heartdisease, restecg, thalach | age, chol, trestbps, fbs)
# (exang _|_ thalach | heartdisease, chol, restecg, trestbps)
# (exang _|_ thalach | heartdisease, chol, restecg, fbs)
# (exang _|_ restecg, thalach | heartdisease, chol, trestbps, fbs)
# (exang _|_ heartdisease, thalach | chol, restecg, trestbps, fbs)
# (exang _|_ chol, restecg | sex, heartdisease, age, thalach)
# (exang _|_ heartdisease, chol, restecg, fbs | sex, age, thalach, trestbps)
# (exang _|_ chol | sex, heartdisease, restecg, thalach)
# (exang _|_ chol, restecg | sex, heartdisease, thalach, trestbps)
# (exang _|_ chol, restecg | sex, heartdisease, thalach, fbs)
# (exang _|_ heartdisease, chol, restecg | sex, thalach, trestbps, fbs)
# (exang _|_ chol, thalach | sex, heartdisease, age, restecg)
# (exang _|_ thalach, chol, restecg, fbs | sex, heartdisease, age, trestbps)
# (exang _|_ thalach, chol, restecg | sex, heartdisease, age, fbs)
# (exang _|_ heartdisease, chol, thalach, fbs | sex, age, restecg, trestbps)
# (exang _|_ heartdisease, chol, restecg, thalach | sex, age, trestbps, fbs)
# (exang _|_ chol, thalach | sex, heartdisease, restecg, trestbps)
# (exang _|_ chol, thalach | sex, heartdisease, restecg, fbs)
# (exang _|_ restecg, chol, thalach | sex, heartdisease, trestbps, fbs)
# (exang _|_ heartdisease, chol, thalach | sex, restecg, trestbps, fbs)
# (exang _|_ chol | heartdisease, age, thalach, restecg)
# (exang _|_ chol, restecg, fbs | heartdisease, age, thalach, trestbps)
# (exang _|_ chol, restecg | heartdisease, age, thalach, fbs)
# (exang _|_ heartdisease, chol, fbs | age, thalach, trestbps, restecg)
# (exang _|_ heartdisease, chol, restecg | age, thalach, trestbps, fbs)
# (exang _|_ chol | heartdisease, restecg, thalach, trestbps)
# (exang _|_ chol | heartdisease, restecg, thalach, fbs)
# (exang _|_ chol, restecg | heartdisease, thalach, trestbps, fbs)
# (exang _|_ heartdisease, chol | restecg, thalach, trestbps, fbs)
# (exang _|_ chol, thalach, fbs | heartdisease, age, restecg, trestbps)
# (exang _|_ chol, thalach | heartdisease, age, restecg, fbs)
# (exang _|_ thalach, chol, restecg | heartdisease, age, trestbps, fbs)
# (exang _|_ heartdisease, chol, thalach | age, restecg, trestbps, fbs)
# (exang _|_ chol, thalach | heartdisease, restecg, trestbps, fbs)
# (exang _|_ restecg | chol, sex, age, heartdisease, thalach)
# (exang _|_ heartdisease, restecg, fbs | chol, sex, age, thalach, trestbps)
# (exang _|_ restecg | chol, sex, heartdisease, thalach, trestbps)
# (exang _|_ restecg | chol, sex, heartdisease, thalach, fbs)
# (exang _|_ heartdisease, restecg | chol, sex, thalach, trestbps, fbs)
# (exang _|_ thalach | chol, sex, age, heartdisease, restecg)
# (exang _|_ thalach, restecg, fbs | chol, sex, age, heartdisease, trestbps)
# (exang _|_ thalach, restecg | chol, sex, age, heartdisease, fbs)
# (exang _|_ heartdisease, thalach, fbs | chol, sex, age, restecg, trestbps)
# (exang _|_ heartdisease, restecg, thalach | chol, sex, age, trestbps, fbs)
# (exang _|_ thalach | chol, sex, heartdisease, restecg, trestbps)
# (exang _|_ thalach | chol, sex, heartdisease, restecg, fbs)
# (exang _|_ restecg, thalach | chol, sex, heartdisease, trestbps, fbs)
# (exang _|_ heartdisease, thalach | chol, sex, restecg, trestbps, fbs)
# (exang _|_ restecg, fbs | chol, age, heartdisease, thalach, trestbps)
# (exang _|_ restecg | chol, age, heartdisease, thalach, fbs)
# (exang _|_ heartdisease, fbs | restecg, chol, age, thalach, trestbps)
# (exang _|_ heartdisease, restecg | chol, age, thalach, trestbps, fbs)
# (exang _|_ restecg | chol, heartdisease, thalach, trestbps, fbs)
# (exang _|_ heartdisease | chol, thalach, restecg, trestbps, fbs)
# (exang _|_ thalach, fbs | chol, age, heartdisease, restecg, trestbps)
# (exang _|_ thalach | chol, age, heartdisease, restecg, fbs)
# (exang _|_ thalach, restecg | chol, age, heartdisease, trestbps, fbs)
# (exang _|_ heartdisease, thalach | chol, age, restecg, trestbps, fbs)
# (exang _|_ thalach | chol, heartdisease, restecg, trestbps, fbs)
# (exang _|_ chol | restecg, sex, age, heartdisease, thalach)
# (exang _|_ chol, restecg, fbs | sex, age, heartdisease, thalach, trestbps)
# (exang _|_ chol, restecg | sex, age, heartdisease, thalach, fbs)
# (exang _|_ heartdisease, chol, fbs | restecg, sex, age, thalach, trestbps)
# (exang _|_ heartdisease, chol, restecg | sex, age, thalach, trestbps, fbs)
# (exang _|_ chol | sex, thalach, heartdisease, restecg, trestbps)
# (exang _|_ chol | sex, thalach, heartdisease, restecg, fbs)
# (exang _|_ chol, restecg | sex, heartdisease, thalach, trestbps, fbs)
# (exang _|_ heartdisease, chol | sex, thalach, restecg, trestbps, fbs)
# (exang _|_ chol, thalach, fbs | sex, age, heartdisease, restecg, trestbps)
# (exang _|_ chol, thalach | sex, age, heartdisease, restecg, fbs)
# (exang _|_ thalach, chol, restecg | sex, age, heartdisease, trestbps, fbs)
# (exang _|_ heartdisease, chol, thalach | sex, age, restecg, trestbps, fbs)
# (exang _|_ chol, thalach | sex, heartdisease, restecg, trestbps, fbs)
# (exang _|_ chol, fbs | restecg, age, heartdisease, thalach, trestbps)
# (exang _|_ chol | restecg, age, heartdisease, thalach, fbs)
# (exang _|_ chol, restecg | age, heartdisease, thalach, trestbps, fbs)
# (exang _|_ heartdisease, chol | restecg, age, thalach, trestbps, fbs)
# (exang _|_ chol | thalach, heartdisease, restecg, trestbps, fbs)
# (exang _|_ chol, thalach | age, heartdisease, restecg, trestbps, fbs)
# (exang _|_ restecg, fbs | chol, sex, age, heartdisease, thalach, trestbps)
# (exang _|_ restecg | chol, sex, age, heartdisease, thalach, fbs)
# (exang _|_ heartdisease, fbs | restecg, chol, sex, age, thalach, trestbps)
# (exang _|_ heartdisease, restecg | chol, sex, age, thalach, trestbps, fbs)
# (exang _|_ restecg | chol, sex, heartdisease, thalach, trestbps, fbs)
# (exang _|_ heartdisease | chol, sex, thalach, restecg, trestbps, fbs)
# (exang _|_ thalach, fbs | chol, sex, age, heartdisease, restecg, trestbps)
# (exang _|_ thalach | chol, sex, age, heartdisease, restecg, fbs)
# (exang _|_ thalach, restecg | chol, sex, age, heartdisease, trestbps, fbs)
# (exang _|_ heartdisease, thalach | chol, sex, age, restecg, trestbps, fbs)
# (exang _|_ thalach | chol, sex, heartdisease, restecg, trestbps, fbs)
# (exang _|_ fbs | restecg, chol, age, heartdisease, thalach, trestbps)
# (exang _|_ restecg | chol, age, heartdisease, thalach, trestbps, fbs)
# (exang _|_ heartdisease | restecg, chol, age, thalach, trestbps, fbs)
# (exang _|_ thalach | chol, age, heartdisease, restecg, trestbps, fbs)
# (exang _|_ chol, fbs | restecg, sex, age, heartdisease, thalach, trestbps)
# (exang _|_ chol | restecg, sex, age, heartdisease, thalach, fbs)
# (exang _|_ chol, restecg | sex, age, heartdisease, thalach, trestbps, fbs)
# (exang _|_ heartdisease, chol | restecg, sex, age, thalach, trestbps, fbs)
# (exang _|_ chol | sex, thalach, heartdisease, restecg, trestbps, fbs)
# (exang _|_ chol, thalach | sex, age, heartdisease, restecg, trestbps, fbs)
# (exang _|_ chol | restecg, age, heartdisease, thalach, trestbps, fbs)
# (exang _|_ fbs | restecg, chol, sex, age, heartdisease, thalach, trestbps)
# (exang _|_ restecg | chol, sex, age, heartdisease, thalach, trestbps, fbs)
# (exang _|_ heartdisease | restecg, chol, sex, age, thalach, trestbps, fbs)
# (exang _|_ thalach | chol, sex, age, heartdisease, restecg, trestbps, fbs)
# (exang _|_ chol | restecg, sex, age, heartdisease, thalach, trestbps, fbs)
# (heartdisease _|_ sex, exang | age, trestbps)
# (heartdisease _|_ sex, age, exang | trestbps, fbs)
# (heartdisease _|_ sex, exang | age, chol, trestbps)
# (heartdisease _|_ sex, age, exang | chol, trestbps, fbs)
# (heartdisease _|_ exang | sex, age, trestbps)
# (heartdisease _|_ age, exang | sex, trestbps, fbs)
# (heartdisease _|_ sex, exang | age, thalach, trestbps)
# (heartdisease _|_ sex, age, exang | thalach, trestbps, fbs)
# (heartdisease _|_ sex | age, trestbps, exang)
# (heartdisease _|_ sex, exang | age, restecg, trestbps)
# (heartdisease _|_ sex, exang | age, trestbps, fbs)
# (heartdisease _|_ sex, age | trestbps, exang, fbs)
# (heartdisease _|_ sex, age, exang | restecg, trestbps, fbs)
# (heartdisease _|_ exang | sex, age, chol, trestbps)
# (heartdisease _|_ age, exang | sex, chol, trestbps, fbs)
# (heartdisease _|_ sex, exang | age, chol, thalach, trestbps)
# (heartdisease _|_ sex, age, exang | chol, thalach, trestbps, fbs)
# (heartdisease _|_ sex | age, chol, trestbps, exang)
# (heartdisease _|_ sex, exang | age, chol, restecg, trestbps)
# (heartdisease _|_ sex, exang | age, chol, trestbps, fbs)
# (heartdisease _|_ sex, age | chol, trestbps, exang, fbs)
# (heartdisease _|_ sex, age, exang | chol, restecg, trestbps, fbs)
# (heartdisease _|_ exang | sex, age, thalach, trestbps)
# (heartdisease _|_ age, exang | sex, thalach, trestbps, fbs)
# ...
# (thalach _|_ sex, restecg, trestbps | chol, age, exang, heartdisease, fbs)
# (thalach _|_ sex | chol, age, exang, restecg, trestbps)
# (thalach _|_ sex | chol, age, exang, trestbps, fbs)
# (thalach _|_ sex, exang, fbs | chol, age, heartdisease, restecg, trestbps)
# (thalach _|_ sex, trestbps, exang | chol, age, heartdisease, restecg, fbs)
# (thalach _|_ sex, restecg, exang | chol, age, heartdisease, trestbps, fbs)
# (thalach _|_ sex, exang | chol, age, restecg, trestbps, fbs)
# (thalach _|_ sex, age, fbs | chol, exang, heartdisease, restecg, trestbps)
# (thalach _|_ sex, age, trestbps | chol, exang, heartdisease, restecg, fbs)
# (thalach _|_ sex, age, restecg | chol, exang, heartdisease, trestbps, fbs)
# (thalach _|_ sex, age | chol, exang, restecg, trestbps, fbs)
# (thalach _|_ sex, age, exang | chol, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ chol, trestbps, fbs | sex, age, exang, heartdisease, restecg)
# (thalach _|_ chol, restecg, fbs | sex, age, exang, heartdisease, trestbps)
# (thalach _|_ chol, restecg, trestbps | sex, age, exang, heartdisease, fbs)
# (thalach _|_ chol, exang, fbs | sex, age, heartdisease, restecg, trestbps)
# (thalach _|_ chol, trestbps, exang | sex, age, heartdisease, restecg, fbs)
# (thalach _|_ chol, restecg, exang | sex, age, heartdisease, trestbps, fbs)
# (thalach _|_ exang | sex, age, restecg, trestbps, fbs)
# (thalach _|_ age, chol, fbs | sex, exang, heartdisease, restecg, trestbps)
# (thalach _|_ age, chol, trestbps | sex, exang, heartdisease, restecg, fbs)
# (thalach _|_ age, chol, restecg | sex, exang, heartdisease, trestbps, fbs)
# (thalach _|_ age | sex, exang, restecg, trestbps, fbs)
# (thalach _|_ age, chol, exang | sex, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ sex, chol, fbs | age, exang, heartdisease, restecg, trestbps)
# (thalach _|_ sex, chol, trestbps | age, exang, heartdisease, restecg, fbs)
# (thalach _|_ sex, chol, restecg | age, exang, heartdisease, trestbps, fbs)
# (thalach _|_ sex | age, exang, restecg, trestbps, fbs)
# (thalach _|_ sex, chol, exang | age, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ sex, age, chol | exang, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ trestbps, fbs | chol, sex, age, exang, heartdisease, restecg)
# (thalach _|_ restecg, fbs | chol, sex, age, exang, heartdisease, trestbps)
# (thalach _|_ restecg, trestbps | chol, sex, age, exang, heartdisease, fbs)
# (thalach _|_ exang, fbs | chol, sex, age, heartdisease, restecg, trestbps)
# (thalach _|_ trestbps, exang | chol, sex, age, heartdisease, restecg, fbs)
# (thalach _|_ restecg, exang | chol, sex, age, heartdisease, trestbps, fbs)
# (thalach _|_ exang | chol, sex, age, restecg, trestbps, fbs)
# (thalach _|_ age, fbs | chol, sex, exang, heartdisease, restecg, trestbps)
# (thalach _|_ age, trestbps | chol, sex, exang, heartdisease, restecg, fbs)
# (thalach _|_ age, restecg | chol, sex, exang, heartdisease, trestbps, fbs)
# (thalach _|_ age | chol, sex, exang, restecg, trestbps, fbs)
# (thalach _|_ age, exang | chol, sex, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ sex, fbs | chol, age, exang, heartdisease, restecg, trestbps)
# (thalach _|_ sex, trestbps | chol, age, exang, heartdisease, restecg, fbs)
# (thalach _|_ sex, restecg | chol, age, exang, heartdisease, trestbps, fbs)
# (thalach _|_ sex | chol, age, exang, restecg, trestbps, fbs)
# (thalach _|_ sex, exang | chol, age, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ sex, age | chol, exang, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ chol, fbs | sex, age, exang, heartdisease, restecg, trestbps)
# (thalach _|_ chol, trestbps | sex, age, exang, heartdisease, restecg, fbs)
# (thalach _|_ chol, restecg | sex, age, exang, heartdisease, trestbps, fbs)
# (thalach _|_ chol, exang | sex, age, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ age, chol | sex, exang, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ sex, chol | age, exang, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ fbs | chol, sex, age, exang, heartdisease, restecg, trestbps)
# (thalach _|_ trestbps | chol, sex, age, exang, heartdisease, restecg, fbs)
# (thalach _|_ restecg | chol, sex, age, exang, heartdisease, trestbps, fbs)
# (thalach _|_ exang | chol, sex, age, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ age | chol, sex, exang, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ sex | chol, age, exang, heartdisease, restecg, trestbps, fbs)
# (thalach _|_ chol | sex, age, exang, heartdisease, restecg, trestbps, fbs)
# (chol _|_ sex, thalach, age, exang, restecg, trestbps, fbs | heartdisease)
# (chol _|_ thalach, age, exang, restecg, trestbps, fbs | sex, heartdisease)
# (chol _|_ sex, age, exang, restecg, trestbps, fbs | heartdisease, thalach)
# (chol _|_ sex, restecg, exang, thalach, trestbps, fbs | heartdisease, age)
# (chol _|_ sex, exang | age, trestbps)
# (chol _|_ sex, thalach, age, restecg, trestbps, fbs | heartdisease, exang)
# (chol _|_ sex, age, exang, thalach, trestbps, fbs | heartdisease, restecg)
# (chol _|_ sex, thalach, age, exang, restecg, fbs | heartdisease, trestbps)
# (chol _|_ sex, thalach, age, exang, restecg, trestbps | heartdisease, fbs)
# (chol _|_ sex, age, exang | trestbps, fbs)
# (chol _|_ age, exang, restecg, trestbps, fbs | sex, heartdisease, thalach)
# (chol _|_ restecg, exang, thalach, trestbps, fbs | sex, heartdisease, age)
# (chol _|_ exang | sex, age, trestbps)
# (chol _|_ thalach, age, restecg, trestbps, fbs | sex, heartdisease, exang)
# (chol _|_ age, exang, thalach, trestbps, fbs | sex, heartdisease, restecg)
# (chol _|_ thalach, age, exang, restecg, fbs | sex, heartdisease, trestbps)
# (chol _|_ thalach, age, exang, restecg, trestbps | sex, heartdisease, fbs)
# (chol _|_ age, exang | sex, trestbps, fbs)
# (chol _|_ sex, exang, restecg, trestbps, fbs | heartdisease, age, thalach)
# (chol _|_ sex, exang | age, thalach, trestbps)
# (chol _|_ sex, age, restecg, trestbps, fbs | heartdisease, thalach, exang)
# (chol _|_ sex, age, exang, trestbps, fbs | heartdisease, restecg, thalach)
# (chol _|_ sex, age, exang, restecg, fbs | heartdisease, thalach, trestbps)
# (chol _|_ sex, age, exang, restecg, trestbps | heartdisease, thalach, fbs)
# (chol _|_ sex, age, exang | thalach, trestbps, fbs)
# (chol _|_ sex, restecg, thalach, trestbps, fbs | heartdisease, age, exang)
# (chol _|_ sex | age, trestbps, exang)
# (chol _|_ sex, exang, thalach, trestbps, fbs | heartdisease, age, restecg)
# (chol _|_ sex, restecg, exang, thalach, fbs | heartdisease, age, trestbps)
# (chol _|_ sex, restecg, exang, thalach, trestbps | heartdisease, age, fbs)
# (chol _|_ sex, exang | age, restecg, trestbps)
# (chol _|_ sex, exang | age, trestbps, fbs)
# (chol _|_ sex, age, thalach, trestbps, fbs | heartdisease, restecg, exang)
# (chol _|_ sex, thalach, age, restecg, fbs | heartdisease, trestbps, exang)
# (chol _|_ sex, thalach, age, restecg, trestbps | heartdisease, exang, fbs)
# (chol _|_ sex, age | trestbps, exang, fbs)
# (chol _|_ sex, age, exang, thalach, fbs | heartdisease, restecg, trestbps)
# (chol _|_ sex, age, exang, thalach, trestbps | heartdisease, restecg, fbs)
# (chol _|_ sex, thalach, age, exang, restecg | heartdisease, trestbps, fbs)
# (chol _|_ sex, age, exang | restecg, trestbps, fbs)
# (chol _|_ restecg, trestbps, exang, fbs | sex, heartdisease, age, thalach)
# (chol _|_ exang | sex, age, thalach, trestbps)
# (chol _|_ age, restecg, trestbps, fbs | sex, heartdisease, thalach, exang)
# (chol _|_ age, trestbps, exang, fbs | sex, heartdisease, restecg, thalach)
# (chol _|_ age, restecg, exang, fbs | sex, heartdisease, thalach, trestbps)
# (chol _|_ age, restecg, trestbps, exang | sex, heartdisease, thalach, fbs)
# (chol _|_ age, exang | sex, thalach, trestbps, fbs)
# (chol _|_ thalach, restecg, trestbps, fbs | sex, heartdisease, age, exang)
# (chol _|_ thalach, trestbps, exang, fbs | sex, heartdisease, age, restecg)
# (chol _|_ thalach, restecg, exang, fbs | sex, heartdisease, age, trestbps)
# (chol _|_ thalach, restecg, trestbps, exang | sex, heartdisease, age, fbs)
# (chol _|_ exang | sex, age, restecg, trestbps)
# (chol _|_ exang | sex, age, trestbps, fbs)
# (chol _|_ age, thalach, trestbps, fbs | sex, heartdisease, restecg, exang)
# (chol _|_ restecg, age, thalach, fbs | sex, heartdisease, trestbps, exang)
# (chol _|_ age, thalach, trestbps, restecg | sex, heartdisease, exang, fbs)
# (chol _|_ age | sex, trestbps, exang, fbs)
# (chol _|_ age, thalach, exang, fbs | sex, heartdisease, restecg, trestbps)
# (chol _|_ age, thalach, trestbps, exang | sex, heartdisease, restecg, fbs)
# (chol _|_ age, thalach, exang, restecg | sex, heartdisease, trestbps, fbs)
# (chol _|_ age, exang | sex, restecg, trestbps, fbs)
# (chol _|_ sex, restecg, trestbps, fbs | heartdisease, age, thalach, exang)
# (chol _|_ sex | age, thalach, trestbps, exang)
# (chol _|_ sex, trestbps, exang, fbs | heartdisease, age, thalach, restecg)
# (chol _|_ sex, restecg, exang, fbs | heartdisease, age, thalach, trestbps)
# (chol _|_ sex, restecg, trestbps, exang | heartdisease, age, thalach, fbs)
# (chol _|_ sex, exang | age, thalach, trestbps, restecg)
# (chol _|_ sex, exang | age, thalach, trestbps, fbs)
# (chol _|_ sex, age, trestbps, fbs | heartdisease, restecg, thalach, exang)
# (chol _|_ sex, age, restecg, fbs | heartdisease, thalach, trestbps, exang)
# (chol _|_ sex, age, restecg, trestbps | heartdisease, thalach, exang, fbs)
# (chol _|_ sex, age | thalach, trestbps, exang, fbs)
# (chol _|_ sex, age, exang, fbs | heartdisease, restecg, thalach, trestbps)
# (chol _|_ sex, age, trestbps, exang | heartdisease, restecg, thalach, fbs)
# (chol _|_ sex, age, restecg, exang | heartdisease, thalach, trestbps, fbs)
# (chol _|_ sex, age, exang | restecg, thalach, trestbps, fbs)
# (chol _|_ sex, thalach, trestbps, fbs | heartdisease, age, restecg, exang)
# (chol _|_ sex, thalach, restecg, fbs | heartdisease, age, trestbps, exang)
# (chol _|_ sex, thalach, restecg, trestbps | heartdisease, age, exang, fbs)
# (chol _|_ sex | age, restecg, trestbps, exang)
# (chol _|_ sex | age, trestbps, exang, fbs)
# (chol _|_ sex, thalach, exang, fbs | heartdisease, age, restecg, trestbps)
# (chol _|_ sex, thalach, trestbps, exang | heartdisease, age, restecg, fbs)
# (chol _|_ sex, thalach, restecg, exang | heartdisease, age, trestbps, fbs)
# (chol _|_ sex, exang | age, restecg, trestbps, fbs)
# (chol _|_ sex, age, thalach, fbs | heartdisease, restecg, trestbps, exang)
# (chol _|_ sex, age, thalach, trestbps | heartdisease, restecg, exang, fbs)
# (chol _|_ sex, age, thalach, restecg | heartdisease, trestbps, exang, fbs)
# (chol _|_ sex, age | restecg, trestbps, exang, fbs)
# (chol _|_ sex, age, thalach, exang | heartdisease, restecg, trestbps, fbs)
# (chol _|_ restecg, trestbps, fbs | sex, age, exang, heartdisease, thalach)
# (chol _|_ trestbps, exang, fbs | restecg, sex, age, heartdisease, thalach)
# (chol _|_ restecg, exang, fbs | sex, age, heartdisease, thalach, trestbps)
# (chol _|_ restecg, trestbps, exang | sex, age, heartdisease, thalach, fbs)
# (chol _|_ exang | restecg, sex, age, thalach, trestbps)
# (chol _|_ exang | sex, age, thalach, trestbps, fbs)
# (chol _|_ age, trestbps, fbs | sex, thalach, exang, heartdisease, restecg)
# (chol _|_ age, restecg, fbs | sex, exang, heartdisease, thalach, trestbps)
# (chol _|_ age, restecg, trestbps | sex, exang, heartdisease, thalach, fbs)
# (chol _|_ age | sex, exang, thalach, trestbps, fbs)
# (chol _|_ age, exang, fbs | sex, thalach, heartdisease, restecg, trestbps)
# (chol _|_ age, trestbps, exang | sex, thalach, heartdisease, restecg, fbs)
# (chol _|_ age, restecg, exang | sex, heartdisease, thalach, trestbps, fbs)
# (chol _|_ age, exang | sex, thalach, restecg, trestbps, fbs)
# (chol _|_ thalach, trestbps, fbs | sex, age, exang, heartdisease, restecg)
# (chol _|_ thalach, restecg, fbs | sex, age, exang, heartdisease, trestbps)
# (chol _|_ thalach, restecg, trestbps | sex, age, exang, heartdisease, fbs)
# (chol _|_ thalach, exang, fbs | sex, age, heartdisease, restecg, trestbps)
# (chol _|_ thalach, trestbps, exang | sex, age, heartdisease, restecg, fbs)
# (chol _|_ thalach, restecg, exang | sex, age, heartdisease, trestbps, fbs)
# (chol _|_ exang | sex, age, restecg, trestbps, fbs)
# (chol _|_ age, thalach, fbs | sex, exang, heartdisease, restecg, trestbps)
# (chol _|_ age, thalach, trestbps | sex, exang, heartdisease, restecg, fbs)
# (chol _|_ age, thalach, restecg | sex, exang, heartdisease, trestbps, fbs)
# (chol _|_ age | sex, exang, restecg, trestbps, fbs)
# (chol _|_ age, thalach, exang | sex, heartdisease, restecg, trestbps, fbs)
# (chol _|_ sex, trestbps, fbs | restecg, age, exang, heartdisease, thalach)
# (chol _|_ sex, restecg, fbs | age, exang, heartdisease, thalach, trestbps)
# (chol _|_ sex, restecg, trestbps | age, exang, heartdisease, thalach, fbs)
# (chol _|_ sex | restecg, age, exang, thalach, trestbps)
# (chol _|_ sex | age, exang, thalach, trestbps, fbs)
# (chol _|_ sex, exang, fbs | restecg, age, heartdisease, thalach, trestbps)
# (chol _|_ sex, trestbps, exang | restecg, age, heartdisease, thalach, fbs)
# (chol _|_ sex, restecg, exang | age, heartdisease, thalach, trestbps, fbs)
# (chol _|_ sex, exang | restecg, age, thalach, trestbps, fbs)
# (chol _|_ sex, age, fbs | thalach, exang, heartdisease, restecg, trestbps)
# (chol _|_ sex, age, trestbps | thalach, exang, heartdisease, restecg, fbs)
# (chol _|_ sex, age, restecg | exang, heartdisease, thalach, trestbps, fbs)
# (chol _|_ sex, age | thalach, exang, restecg, trestbps, fbs)
# (chol _|_ sex, age, exang | thalach, heartdisease, restecg, trestbps, fbs)
# (chol _|_ sex, thalach, fbs | age, exang, heartdisease, restecg, trestbps)
# (chol _|_ sex, thalach, trestbps | age, exang, heartdisease, restecg, fbs)
# (chol _|_ sex, thalach, restecg | age, exang, heartdisease, trestbps, fbs)
# (chol _|_ sex | age, exang, restecg, trestbps, fbs)
# (chol _|_ sex, thalach, exang | age, heartdisease, restecg, trestbps, fbs)
# (chol _|_ sex, age, thalach | exang, heartdisease, restecg, trestbps, fbs)
# (chol _|_ trestbps, fbs | restecg, sex, age, exang, heartdisease, thalach)
# (chol _|_ restecg, fbs | sex, age, exang, heartdisease, thalach, trestbps)
# (chol _|_ restecg, trestbps | sex, age, exang, heartdisease, thalach, fbs)
# (chol _|_ exang, fbs | restecg, sex, age, heartdisease, thalach, trestbps)
# (chol _|_ trestbps, exang | restecg, sex, age, heartdisease, thalach, fbs)
# (chol _|_ restecg, exang | sex, age, heartdisease, thalach, trestbps, fbs)
# (chol _|_ exang | restecg, sex, age, thalach, trestbps, fbs)
# (chol _|_ age, fbs | sex, thalach, exang, heartdisease, restecg, trestbps)
# (chol _|_ age, trestbps | sex, thalach, exang, heartdisease, restecg, fbs)
# (chol _|_ age, restecg | sex, exang, heartdisease, thalach, trestbps, fbs)
# (chol _|_ age | sex, thalach, exang, restecg, trestbps, fbs)
# (chol _|_ age, exang | sex, thalach, heartdisease, restecg, trestbps, fbs)
# (chol _|_ thalach, fbs | sex, age, exang, heartdisease, restecg, trestbps)
# (chol _|_ thalach, trestbps | sex, age, exang, heartdisease, restecg, fbs)
# (chol _|_ thalach, restecg | sex, age, exang, heartdisease, trestbps, fbs)
# (chol _|_ thalach, exang | sex, age, heartdisease, restecg, trestbps, fbs)
# (chol _|_ age, thalach | sex, exang, heartdisease, restecg, trestbps, fbs)
# (chol _|_ sex, fbs | restecg, age, exang, heartdisease, thalach, trestbps)
# (chol _|_ sex, trestbps | restecg, age, exang, heartdisease, thalach, fbs)
# (chol _|_ sex, restecg | age, exang, heartdisease, thalach, trestbps, fbs)
# (chol _|_ sex | restecg, age, exang, thalach, trestbps, fbs)
# (chol _|_ sex, exang | restecg, age, heartdisease, thalach, trestbps, fbs)
# (chol _|_ sex, age | thalach, exang, heartdisease, restecg, trestbps, fbs)
# (chol _|_ sex, thalach | age, exang, heartdisease, restecg, trestbps, fbs)
# (chol _|_ fbs | restecg, sex, age, exang, heartdisease, thalach, trestbps)
# (chol _|_ trestbps | restecg, sex, age, exang, heartdisease, thalach, fbs)
# (chol _|_ restecg | sex, age, exang, heartdisease, thalach, trestbps, fbs)
# (chol _|_ exang | restecg, sex, age, heartdisease, thalach, trestbps, fbs)
# (chol _|_ age | sex, thalach, exang, heartdisease, restecg, trestbps, fbs)
# (chol _|_ thalach | sex, age, exang, heartdisease, restecg, trestbps, fbs)
# (chol _|_ sex | restecg, age, exang, heartdisease, thalach, trestbps, fbs)

# %% [markdown]
# ###### Inferencing with Bayesian Network

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
heart_disease_infer = VariableElimination(model)

# Computing the probability of bronc given smoke.
query = heart_disease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(query)
# Out:
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<00:00, 2186.49it/s]
# Eliminating: fbs: 100%|██████████| 7/7 [00:00<00:00, 228.51it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.4919 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.5081 |
# +-----------------+---------------------+

# %%
# Out:
# <style> div.prompt_container{ width: 0px; min-width: 0px; visibility: collapse}</style>
# <style> div.prompt{ width: 0px; min-width: 0px; visibility: collapse}</style>
# <style> div.output pre { font-style: italic; color: rgb(105,105,105) } </style>
# <style>.container { width:100% !important; }</style>
