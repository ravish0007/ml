# %% [markdown]
# # 7 : Construct a Bayesian Network to demonstrate the diagnosis of heart patients using standard Heart Disease

# %%
# Install if the module doesn't exist
! pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in /usr/local/lib/python3.7/dist-packages (0.1.9)

# %% [markdown]
# ###### Importing Heart Disease Data Set and Customizing

# %%
import pandas as pd
from urllib.request import urlopen

#data_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
data_url = 'https://tinyurl.com/processed-hungarian-data'


#names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']

names = urlopen('https://tinyurl.com/names-csv').read().decode().split(',')   # need a live connection

data = urlopen(data_url)
heart_disease = pd.read_csv(data, names = names)                              # gets Cleveland data

heart_disease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %% [markdown]
# ###### Dropping columns which are more non numeric

# %%
heart_disease.drop(['ca', 'slope', 'thal', 'oldpeak'], axis=1)

# also replacing '?' with numpy's NaN ( not a number)

import numpy

heart_disease = heart_disease.replace('?', numpy.NaN)

# %% [markdown]
# ### Modeling Heart Disease Data
# <img src ="heart.png">

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

associations_list =  [
                       ('age', 'trestbps'),       ('age', 'fbs'),             ('sex', 'trestbps'),  
                       ('exang', 'trestbps'),     ('trestbps','heartdisease'),('fbs','heartdisease'),
                       ('heartdisease','restecg'),('heartdisease','thalach'), ('heartdisease','chol')
                    ]
model = BayesianModel(associations_list)

# Learing CPDs using Maximum Likelihood Estimators
model.fit(heart_disease, estimator=MaximumLikelihoodEstimator)

# %%
print(model.get_cpds('age'))
# Out:
# +---------+---+
# | age(28) | 0 |
# +---------+---+
# | age(29) | 0 |
# +---------+---+
# | age(30) | 0 |
# +---------+---+
# | age(31) | 0 |
# +---------+---+
# | age(32) | 0 |
# +---------+---+
# | age(33) | 0 |
# +---------+---+
# | age(34) | 0 |
# +---------+---+
# | age(35) | 0 |
# +---------+---+
# | age(36) | 0 |
# +---------+---+
# | age(37) | 0 |
# +---------+---+
# | age(38) | 0 |
# +---------+---+
# | age(39) | 0 |
# +---------+---+
# | age(40) | 0 |
# +---------+---+
# | age(41) | 0 |
# +---------+---+
# | age(42) | 0 |
# +---------+---+
# | age(43) | 0 |
# +---------+---+
# | age(44) | 0 |
# +---------+---+
# | age(45) | 0 |
# +---------+---+
# | age(46) | 0 |
# +---------+---+
# | age(47) | 1 |
# +---------+---+
# | age(48) | 0 |
# +---------+---+
# | age(49) | 0 |
# +---------+---+
# | age(50) | 0 |
# +---------+---+
# | age(51) | 0 |
# +---------+---+
# | age(52) | 0 |
# +---------+---+
# | age(53) | 0 |
# +---------+---+
# | age(54) | 0 |
# +---------+---+
# | age(55) | 0 |
# +---------+---+
# | age(56) | 0 |
# +---------+---+
# | age(57) | 0 |
# +---------+---+
# | age(58) | 0 |
# +---------+---+
# | age(59) | 0 |
# +---------+---+
# | age(60) | 0 |
# +---------+---+
# | age(61) | 0 |
# +---------+---+
# | age(62) | 0 |
# +---------+---+
# | age(63) | 0 |
# +---------+---+
# | age(65) | 0 |
# +---------+---+
# | age(66) | 0 |
# +---------+---+

# %%
print(model.get_cpds('sex'))
# Out:
# +--------+---+
# | sex(0) | 0 |
# +--------+---+
# | sex(1) | 1 |
# +--------+---+

# %%
model.get_independencies()
# Out:
# (age _|_ exang, sex)
# (age _|_ exang | sex)
# (age _|_ exang, sex | fbs)
# (age _|_ sex | exang)
# (age _|_ thalach, chol, restecg | heartdisease)
# (age _|_ exang | fbs, sex)
# (age _|_ thalach, chol, restecg | heartdisease, sex)
# (age _|_ thalach, restecg | chol, heartdisease)
# (age _|_ chol, thalach | restecg, heartdisease)
# (age _|_ sex | fbs, exang)
# (age _|_ thalach, chol, restecg, heartdisease | trestbps, fbs)
# (age _|_ thalach, chol, restecg | fbs, heartdisease)
# (age _|_ chol, restecg | thalach, heartdisease)
# (age _|_ thalach, chol, restecg | exang, heartdisease)
# (age _|_ thalach, chol, restecg | trestbps, heartdisease)
# (age _|_ thalach, restecg | chol, heartdisease, sex)
# (age _|_ chol, thalach | restecg, heartdisease, sex)
# (age _|_ thalach, chol, restecg, heartdisease | trestbps, fbs, sex)
# (age _|_ thalach, chol, restecg | fbs, heartdisease, sex)
# (age _|_ chol, restecg | thalach, heartdisease, sex)
# (age _|_ thalach, chol, restecg | heartdisease, exang, sex)
# (age _|_ thalach, chol, restecg | trestbps, heartdisease, sex)
# (age _|_ thalach | chol, restecg, heartdisease)
# (age _|_ thalach, restecg, heartdisease | fbs, chol, trestbps)
# (age _|_ thalach, restecg | fbs, chol, heartdisease)
# (age _|_ restecg | chol, thalach, heartdisease)
# (age _|_ thalach, restecg | chol, exang, heartdisease)
# (age _|_ thalach, restecg | trestbps, chol, heartdisease)
# (age _|_ chol, thalach, heartdisease | trestbps, fbs, restecg)
# (age _|_ chol, thalach | fbs, restecg, heartdisease)
# (age _|_ chol | thalach, restecg, heartdisease)
# (age _|_ chol, thalach | restecg, exang, heartdisease)
# (age _|_ chol, thalach | trestbps, restecg, heartdisease)
# (age _|_ chol, restecg, heartdisease | trestbps, fbs, thalach)
# (age _|_ chol, restecg | fbs, thalach, heartdisease)
# (age _|_ thalach, chol, restecg, heartdisease | trestbps, fbs, exang)
# (age _|_ thalach, chol, restecg | fbs, exang, heartdisease)
# (age _|_ thalach, chol, restecg | trestbps, fbs, heartdisease)
# (age _|_ chol, restecg | thalach, exang, heartdisease)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease)
# (age _|_ thalach, chol, restecg | trestbps, exang, heartdisease)
# (age _|_ thalach | chol, restecg, heartdisease, sex)
# (age _|_ restecg, thalach, heartdisease | fbs, chol, trestbps, sex)
# (age _|_ restecg, thalach | fbs, chol, heartdisease, sex)
# (age _|_ restecg | chol, thalach, heartdisease, sex)
# (age _|_ restecg, thalach | chol, heartdisease, exang, sex)
# (age _|_ restecg, thalach | trestbps, chol, heartdisease, sex)
# (age _|_ chol, thalach, heartdisease | trestbps, fbs, restecg, sex)
# (age _|_ chol, thalach | fbs, restecg, heartdisease, sex)
# (age _|_ chol | thalach, restecg, heartdisease, sex)
# (age _|_ chol, thalach | heartdisease, restecg, exang, sex)
# (age _|_ chol, thalach | trestbps, restecg, heartdisease, sex)
# (age _|_ chol, restecg, heartdisease | trestbps, fbs, thalach, sex)
# (age _|_ chol, restecg | fbs, thalach, heartdisease, sex)
# (age _|_ restecg, chol, thalach, heartdisease | trestbps, fbs, exang, sex)
# (age _|_ restecg, chol, thalach | fbs, heartdisease, exang, sex)
# (age _|_ restecg, chol, thalach | trestbps, fbs, heartdisease, sex)
# (age _|_ chol, restecg | heartdisease, thalach, exang, sex)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease, sex)
# (age _|_ restecg, chol, thalach | trestbps, heartdisease, exang, sex)
# (age _|_ thalach, heartdisease | fbs, chol, restecg, trestbps)
# (age _|_ thalach | fbs, chol, restecg, heartdisease)
# (age _|_ thalach | chol, restecg, exang, heartdisease)
# (age _|_ thalach | trestbps, chol, restecg, heartdisease)
# (age _|_ restecg, heartdisease | fbs, chol, thalach, trestbps)
# (age _|_ restecg | fbs, chol, thalach, heartdisease)
# (age _|_ restecg, thalach, heartdisease | fbs, chol, trestbps, exang)
# (age _|_ restecg, thalach | fbs, chol, exang, heartdisease)
# (age _|_ restecg, thalach | fbs, chol, trestbps, heartdisease)
# (age _|_ restecg | chol, thalach, exang, heartdisease)
# (age _|_ restecg | trestbps, chol, thalach, heartdisease)
# (age _|_ restecg, thalach | trestbps, chol, exang, heartdisease)
# (age _|_ chol, heartdisease | thalach, trestbps, fbs, restecg)
# (age _|_ chol | thalach, fbs, restecg, heartdisease)
# (age _|_ chol, thalach, heartdisease | trestbps, fbs, restecg, exang)
# (age _|_ chol, thalach | fbs, restecg, exang, heartdisease)
# (age _|_ chol, thalach | trestbps, fbs, restecg, heartdisease)
# (age _|_ chol | thalach, restecg, exang, heartdisease)
# (age _|_ chol | thalach, trestbps, restecg, heartdisease)
# (age _|_ chol, thalach | trestbps, restecg, exang, heartdisease)
# (age _|_ chol, restecg, heartdisease | trestbps, fbs, thalach, exang)
# (age _|_ chol, restecg | fbs, thalach, exang, heartdisease)
# (age _|_ chol, restecg | trestbps, fbs, thalach, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, fbs, exang, heartdisease)
# (age _|_ chol, restecg | trestbps, thalach, exang, heartdisease)
# (age _|_ thalach, heartdisease | sex, chol, restecg, fbs, trestbps)
# (age _|_ thalach | sex, chol, restecg, fbs, heartdisease)
# (age _|_ thalach | sex, chol, restecg, exang, heartdisease)
# (age _|_ thalach | sex, chol, restecg, trestbps, heartdisease)
# (age _|_ restecg, heartdisease | sex, chol, fbs, thalach, trestbps)
# (age _|_ restecg | sex, chol, fbs, thalach, heartdisease)
# (age _|_ restecg, thalach, heartdisease | sex, chol, fbs, exang, trestbps)
# (age _|_ restecg, thalach | sex, chol, fbs, exang, heartdisease)
# (age _|_ restecg, thalach | sex, chol, fbs, trestbps, heartdisease)
# (age _|_ restecg | sex, chol, thalach, exang, heartdisease)
# (age _|_ restecg | sex, chol, thalach, trestbps, heartdisease)
# (age _|_ restecg, thalach | sex, chol, exang, trestbps, heartdisease)
# (age _|_ chol, heartdisease | sex, restecg, fbs, thalach, trestbps)
# (age _|_ chol | sex, restecg, fbs, thalach, heartdisease)
# (age _|_ chol, thalach, heartdisease | sex, restecg, fbs, exang, trestbps)
# (age _|_ chol, thalach | sex, restecg, fbs, exang, heartdisease)
# (age _|_ chol, thalach | sex, restecg, fbs, trestbps, heartdisease)
# (age _|_ chol | sex, restecg, thalach, exang, heartdisease)
# (age _|_ chol | sex, restecg, thalach, trestbps, heartdisease)
# (age _|_ chol, thalach | sex, restecg, exang, trestbps, heartdisease)
# (age _|_ chol, restecg, heartdisease | sex, fbs, thalach, exang, trestbps)
# (age _|_ chol, restecg | sex, fbs, thalach, exang, heartdisease)
# (age _|_ chol, restecg | sex, fbs, thalach, trestbps, heartdisease)
# (age _|_ restecg, chol, thalach | sex, fbs, exang, trestbps, heartdisease)
# (age _|_ chol, restecg | sex, thalach, exang, trestbps, heartdisease)
# (age _|_ heartdisease | chol, restecg, fbs, thalach, trestbps)
# (age _|_ thalach, heartdisease | chol, restecg, fbs, exang, trestbps)
# (age _|_ thalach | chol, restecg, fbs, exang, heartdisease)
# (age _|_ thalach | chol, restecg, fbs, trestbps, heartdisease)
# (age _|_ thalach | chol, restecg, exang, trestbps, heartdisease)
# (age _|_ restecg, heartdisease | chol, fbs, thalach, exang, trestbps)
# (age _|_ restecg | chol, fbs, thalach, exang, heartdisease)
# (age _|_ restecg | chol, fbs, thalach, trestbps, heartdisease)
# (age _|_ restecg, thalach | chol, fbs, exang, trestbps, heartdisease)
# (age _|_ restecg | chol, thalach, exang, trestbps, heartdisease)
# (age _|_ chol, heartdisease | restecg, fbs, thalach, exang, trestbps)
# (age _|_ chol | restecg, fbs, thalach, exang, heartdisease)
# (age _|_ chol | restecg, fbs, thalach, trestbps, heartdisease)
# (age _|_ chol, thalach | restecg, fbs, exang, trestbps, heartdisease)
# (age _|_ chol | restecg, thalach, exang, trestbps, heartdisease)
# (age _|_ chol, restecg | fbs, thalach, exang, trestbps, heartdisease)
# (age _|_ heartdisease | sex, chol, restecg, fbs, thalach, trestbps)
# (age _|_ thalach, heartdisease | sex, chol, restecg, fbs, exang, trestbps)
# (age _|_ thalach | sex, chol, restecg, fbs, exang, heartdisease)
# (age _|_ thalach | sex, chol, restecg, fbs, trestbps, heartdisease)
# (age _|_ thalach | sex, chol, restecg, exang, trestbps, heartdisease)
# (age _|_ restecg, heartdisease | sex, chol, fbs, thalach, exang, trestbps)
# (age _|_ restecg | sex, chol, fbs, thalach, exang, heartdisease)
# (age _|_ restecg | sex, chol, fbs, thalach, trestbps, heartdisease)
# (age _|_ restecg, thalach | sex, chol, fbs, exang, trestbps, heartdisease)
# (age _|_ restecg | sex, chol, thalach, exang, trestbps, heartdisease)
# (age _|_ chol, heartdisease | sex, restecg, fbs, thalach, exang, trestbps)
# (age _|_ chol | sex, restecg, fbs, thalach, exang, heartdisease)
# (age _|_ chol | sex, restecg, fbs, thalach, trestbps, heartdisease)
# (age _|_ chol, thalach | sex, restecg, fbs, exang, trestbps, heartdisease)
# (age _|_ chol | sex, restecg, thalach, exang, trestbps, heartdisease)
# (age _|_ chol, restecg | sex, fbs, thalach, exang, trestbps, heartdisease)
# (age _|_ heartdisease | chol, restecg, fbs, thalach, exang, trestbps)
# (age _|_ thalach | chol, restecg, fbs, exang, trestbps, heartdisease)
# (age _|_ restecg | chol, fbs, thalach, exang, trestbps, heartdisease)
# (age _|_ chol | restecg, fbs, thalach, exang, trestbps, heartdisease)
# (age _|_ heartdisease | sex, chol, restecg, fbs, thalach, exang, trestbps)
# (age _|_ thalach | sex, chol, restecg, fbs, exang, trestbps, heartdisease)
# (age _|_ restecg | sex, chol, fbs, thalach, exang, trestbps, heartdisease)
# (age _|_ chol | sex, restecg, fbs, thalach, exang, trestbps, heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, chol, restecg | heartdisease)
# (trestbps _|_ fbs | sex, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex)
# (trestbps _|_ thalach, restecg | chol, heartdisease)
# (trestbps _|_ chol, thalach | restecg, heartdisease)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, age)
# (trestbps _|_ thalach, chol, restecg | fbs, heartdisease)
# (trestbps _|_ chol, restecg | thalach, heartdisease)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease, sex)
# (trestbps _|_ chol, thalach | restecg, heartdisease, sex)
# (trestbps _|_ fbs | exang, sex, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex, age)
# (trestbps _|_ thalach, chol, restecg | fbs, heartdisease, sex)
# (trestbps _|_ chol, restecg | thalach, heartdisease, sex)
# (trestbps _|_ thalach, chol, restecg | heartdisease, exang, sex)
# (trestbps _|_ thalach | chol, restecg, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease, age)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease)
# (trestbps _|_ restecg | chol, thalach, heartdisease)
# (trestbps _|_ thalach, restecg | chol, exang, heartdisease)
# (trestbps _|_ chol, thalach | restecg, heartdisease, age)
# (trestbps _|_ chol, thalach | fbs, restecg, heartdisease)
# (trestbps _|_ chol | thalach, restecg, heartdisease)
# (trestbps _|_ chol, thalach | restecg, exang, heartdisease)
# (trestbps _|_ thalach, chol, restecg | fbs, heartdisease, age)
# (trestbps _|_ chol, restecg | thalach, heartdisease, age)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease, age)
# (trestbps _|_ chol, restecg | fbs, thalach, heartdisease)
# (trestbps _|_ thalach, chol, restecg | fbs, exang, heartdisease)
# (trestbps _|_ chol, restecg | thalach, exang, heartdisease)
# (trestbps _|_ thalach | chol, restecg, heartdisease, sex)
# (trestbps _|_ restecg, thalach | chol, heartdisease, sex, age)
# (trestbps _|_ restecg, thalach | fbs, chol, heartdisease, sex)
# (trestbps _|_ restecg | chol, thalach, heartdisease, sex)
# (trestbps _|_ restecg, thalach | chol, heartdisease, exang, sex)
# (trestbps _|_ chol, thalach | restecg, heartdisease, sex, age)
# (trestbps _|_ chol, thalach | fbs, restecg, heartdisease, sex)
# (trestbps _|_ chol | thalach, restecg, heartdisease, sex)
# (trestbps _|_ chol, thalach | heartdisease, restecg, exang, sex)
# (trestbps _|_ restecg, chol, thalach | fbs, heartdisease, sex, age)
# (trestbps _|_ chol, restecg | thalach, heartdisease, sex, age)
# (trestbps _|_ restecg, chol, thalach | heartdisease, exang, sex, age)
# (trestbps _|_ chol, restecg | fbs, thalach, heartdisease, sex)
# (trestbps _|_ restecg, chol, thalach | fbs, heartdisease, exang, sex)
# (trestbps _|_ chol, restecg | heartdisease, thalach, exang, sex)
# (trestbps _|_ thalach | chol, restecg, heartdisease, age)
# (trestbps _|_ thalach | fbs, chol, restecg, heartdisease)
# (trestbps _|_ thalach | chol, restecg, exang, heartdisease)
# (trestbps _|_ restecg, thalach | fbs, chol, heartdisease, age)
# (trestbps _|_ restecg | chol, thalach, heartdisease, age)
# (trestbps _|_ restecg, thalach | chol, exang, heartdisease, age)
# (trestbps _|_ restecg | fbs, chol, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | fbs, chol, exang, heartdisease)
# (trestbps _|_ restecg | chol, thalach, exang, heartdisease)
# (trestbps _|_ chol, thalach | fbs, restecg, heartdisease, age)
# (trestbps _|_ chol | thalach, restecg, heartdisease, age)
# (trestbps _|_ chol, thalach | restecg, exang, heartdisease, age)
# (trestbps _|_ chol | thalach, fbs, restecg, heartdisease)
# (trestbps _|_ chol, thalach | fbs, restecg, exang, heartdisease)
# (trestbps _|_ chol | thalach, restecg, exang, heartdisease)
# (trestbps _|_ chol, restecg | fbs, thalach, heartdisease, age)
# (trestbps _|_ restecg, chol, thalach | fbs, exang, heartdisease, age)
# (trestbps _|_ chol, restecg | thalach, exang, heartdisease, age)
# (trestbps _|_ chol, restecg | fbs, thalach, exang, heartdisease)
# (trestbps _|_ thalach | sex, chol, restecg, age, heartdisease)
# (trestbps _|_ thalach | sex, chol, restecg, fbs, heartdisease)
# (trestbps _|_ thalach | sex, chol, restecg, exang, heartdisease)
# (trestbps _|_ restecg, thalach | sex, chol, age, fbs, heartdisease)
# (trestbps _|_ restecg | sex, chol, age, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, chol, age, exang, heartdisease)
# (trestbps _|_ restecg | sex, chol, fbs, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, chol, fbs, exang, heartdisease)
# (trestbps _|_ restecg | sex, chol, thalach, exang, heartdisease)
# (trestbps _|_ chol, thalach | sex, restecg, age, fbs, heartdisease)
# (trestbps _|_ chol | sex, restecg, age, thalach, heartdisease)
# (trestbps _|_ chol, thalach | sex, restecg, age, exang, heartdisease)
# (trestbps _|_ chol | sex, restecg, fbs, thalach, heartdisease)
# (trestbps _|_ chol, thalach | sex, restecg, fbs, exang, heartdisease)
# (trestbps _|_ chol | sex, restecg, thalach, exang, heartdisease)
# (trestbps _|_ chol, restecg | sex, age, fbs, thalach, heartdisease)
# (trestbps _|_ restecg, chol, thalach | sex, age, fbs, exang, heartdisease)
# (trestbps _|_ chol, restecg | sex, age, thalach, exang, heartdisease)
# (trestbps _|_ chol, restecg | sex, fbs, thalach, exang, heartdisease)
# (trestbps _|_ thalach | chol, restecg, age, fbs, heartdisease)
# (trestbps _|_ thalach | chol, restecg, age, exang, heartdisease)
# (trestbps _|_ thalach | chol, restecg, fbs, exang, heartdisease)
# (trestbps _|_ restecg | chol, age, fbs, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | chol, age, fbs, exang, heartdisease)
# (trestbps _|_ restecg | chol, age, thalach, exang, heartdisease)
# (trestbps _|_ restecg | chol, fbs, thalach, exang, heartdisease)
# (trestbps _|_ chol | restecg, age, fbs, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, age, fbs, exang, heartdisease)
# (trestbps _|_ chol | restecg, age, thalach, exang, heartdisease)
# (trestbps _|_ chol | restecg, fbs, thalach, exang, heartdisease)
# (trestbps _|_ chol, restecg | age, fbs, thalach, exang, heartdisease)
# (trestbps _|_ thalach | sex, chol, restecg, age, fbs, heartdisease)
# (trestbps _|_ thalach | sex, chol, restecg, age, exang, heartdisease)
# (trestbps _|_ thalach | sex, chol, restecg, fbs, exang, heartdisease)
# (trestbps _|_ restecg | sex, chol, age, fbs, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, chol, age, fbs, exang, heartdisease)
# (trestbps _|_ restecg | sex, chol, age, thalach, exang, heartdisease)
# (trestbps _|_ restecg | sex, chol, fbs, thalach, exang, heartdisease)
# (trestbps _|_ chol | sex, restecg, age, fbs, thalach, heartdisease)
# (trestbps _|_ chol, thalach | sex, restecg, age, fbs, exang, heartdisease)
# (trestbps _|_ chol | sex, restecg, age, thalach, exang, heartdisease)
# (trestbps _|_ chol | sex, restecg, fbs, thalach, exang, heartdisease)
# (trestbps _|_ chol, restecg | sex, age, fbs, thalach, exang, heartdisease)
# (trestbps _|_ thalach | chol, restecg, age, fbs, exang, heartdisease)
# (trestbps _|_ restecg | chol, age, fbs, thalach, exang, heartdisease)
# (trestbps _|_ chol | restecg, age, fbs, thalach, exang, heartdisease)
# (trestbps _|_ thalach | sex, chol, restecg, age, fbs, exang, heartdisease)
# (trestbps _|_ restecg | sex, chol, age, fbs, thalach, exang, heartdisease)
# (trestbps _|_ chol | sex, restecg, age, fbs, thalach, exang, heartdisease)
# (fbs _|_ exang, sex)
# (fbs _|_ exang | sex)
# (fbs _|_ trestbps, exang, sex | age)
# (fbs _|_ sex | exang)
# (fbs _|_ thalach, chol, restecg | heartdisease)
# (fbs _|_ trestbps, exang | sex, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, sex)
# (fbs _|_ thalach, restecg | chol, heartdisease)
# (fbs _|_ chol, thalach | restecg, heartdisease)
# (fbs _|_ trestbps, sex | exang, age)
# (fbs _|_ exang, sex | trestbps, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, age)
# (fbs _|_ chol, restecg | thalach, heartdisease)
# (fbs _|_ thalach, chol, restecg | exang, heartdisease)
# (fbs _|_ thalach, chol, restecg | trestbps, heartdisease)
# (fbs _|_ thalach, restecg | chol, heartdisease, sex)
# (fbs _|_ chol, thalach | restecg, heartdisease, sex)
# (fbs _|_ trestbps | exang, sex, age)
# (fbs _|_ exang | trestbps, sex, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, sex, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, sex)
# (fbs _|_ thalach, chol, restecg | heartdisease, exang, sex)
# (fbs _|_ thalach, chol, restecg | trestbps, heartdisease, sex)
# (fbs _|_ thalach | chol, restecg, heartdisease)
# (fbs _|_ exang, sex | trestbps, chol, age)
# (fbs _|_ thalach, restecg | chol, heartdisease, age)
# (fbs _|_ restecg | chol, thalach, heartdisease)
# (fbs _|_ thalach, restecg | chol, exang, heartdisease)
# (fbs _|_ thalach, restecg | trestbps, chol, heartdisease)
# (fbs _|_ exang, sex | trestbps, restecg, age)
# (fbs _|_ chol, thalach | restecg, heartdisease, age)
# (fbs _|_ chol | thalach, restecg, heartdisease)
# (fbs _|_ chol, thalach | restecg, exang, heartdisease)
# (fbs _|_ chol, thalach | trestbps, restecg, heartdisease)
# (fbs _|_ exang, sex | trestbps, thalach, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, age)
# (fbs _|_ sex | trestbps, exang, age)
# (fbs _|_ thalach, chol, restecg | exang, heartdisease, age)
# (fbs _|_ thalach, exang, sex, chol, restecg | trestbps, heartdisease, age)
# (fbs _|_ chol, restecg | thalach, exang, heartdisease)
# (fbs _|_ chol, restecg | trestbps, thalach, heartdisease)
# (fbs _|_ thalach, chol, restecg | trestbps, exang, heartdisease)
# (fbs _|_ thalach | chol, restecg, heartdisease, sex)
# (fbs _|_ exang | trestbps, chol, sex, age)
# (fbs _|_ restecg, thalach | chol, heartdisease, sex, age)
# (fbs _|_ restecg | chol, thalach, heartdisease, sex)
# (fbs _|_ restecg, thalach | chol, heartdisease, exang, sex)
# (fbs _|_ restecg, thalach | trestbps, chol, heartdisease, sex)
# (fbs _|_ exang | trestbps, restecg, sex, age)
# (fbs _|_ chol, thalach | restecg, heartdisease, sex, age)
# (fbs _|_ chol | thalach, restecg, heartdisease, sex)
# (fbs _|_ chol, thalach | heartdisease, restecg, exang, sex)
# (fbs _|_ chol, thalach | trestbps, restecg, heartdisease, sex)
# (fbs _|_ exang | trestbps, thalach, sex, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, sex, age)
# (fbs _|_ restecg, chol, thalach | heartdisease, exang, sex, age)
# (fbs _|_ restecg, chol, thalach, exang | trestbps, heartdisease, sex, age)
# (fbs _|_ chol, restecg | heartdisease, thalach, exang, sex)
# (fbs _|_ chol, restecg | trestbps, thalach, heartdisease, sex)
# (fbs _|_ restecg, chol, thalach | trestbps, heartdisease, exang, sex)
# (fbs _|_ exang, sex | trestbps, chol, restecg, age)
# (fbs _|_ thalach | chol, restecg, heartdisease, age)
# (fbs _|_ thalach | chol, restecg, exang, heartdisease)
# (fbs _|_ thalach | trestbps, chol, restecg, heartdisease)
# (fbs _|_ exang, sex | trestbps, chol, thalach, age)
# (fbs _|_ restecg | chol, thalach, heartdisease, age)
# (fbs _|_ sex | trestbps, chol, exang, age)
# (fbs _|_ restecg, thalach | chol, exang, heartdisease, age)
# (fbs _|_ restecg, thalach, exang, sex | trestbps, chol, heartdisease, age)
# (fbs _|_ restecg | chol, thalach, exang, heartdisease)
# (fbs _|_ restecg | trestbps, chol, thalach, heartdisease)
# (fbs _|_ restecg, thalach | trestbps, chol, exang, heartdisease)
# (fbs _|_ exang, sex | thalach, trestbps, restecg, age)
# (fbs _|_ chol | thalach, restecg, heartdisease, age)
# (fbs _|_ sex | trestbps, restecg, exang, age)
# (fbs _|_ chol, thalach | restecg, exang, heartdisease, age)
# (fbs _|_ chol, thalach, exang, sex | trestbps, restecg, heartdisease, age)
# (fbs _|_ chol | thalach, restecg, exang, heartdisease)
# (fbs _|_ chol | thalach, trestbps, restecg, heartdisease)
# (fbs _|_ chol, thalach | trestbps, restecg, exang, heartdisease)
# (fbs _|_ sex | trestbps, thalach, exang, age)
# (fbs _|_ chol, restecg | thalach, exang, heartdisease, age)
# (fbs _|_ chol, restecg, exang, sex | trestbps, thalach, heartdisease, age)
# (fbs _|_ restecg, chol, thalach, sex | trestbps, exang, heartdisease, age)
# (fbs _|_ chol, restecg | trestbps, thalach, exang, heartdisease)
# (fbs _|_ exang | sex, chol, restecg, age, trestbps)
# (fbs _|_ thalach | sex, chol, restecg, age, heartdisease)
# (fbs _|_ thalach | sex, chol, restecg, exang, heartdisease)
# (fbs _|_ thalach | sex, chol, restecg, trestbps, heartdisease)
# (fbs _|_ exang | sex, chol, age, thalach, trestbps)
# (fbs _|_ restecg | sex, chol, age, thalach, heartdisease)
# (fbs _|_ restecg, thalach | sex, chol, age, exang, heartdisease)
# (fbs _|_ restecg, thalach, exang | sex, chol, age, trestbps, heartdisease)
# (fbs _|_ restecg | sex, chol, thalach, exang, heartdisease)
# (fbs _|_ restecg | sex, chol, thalach, trestbps, heartdisease)
# (fbs _|_ restecg, thalach | sex, chol, exang, trestbps, heartdisease)
# (fbs _|_ exang | sex, restecg, age, thalach, trestbps)
# (fbs _|_ chol | sex, restecg, age, thalach, heartdisease)
# (fbs _|_ chol, thalach | sex, restecg, age, exang, heartdisease)
# (fbs _|_ chol, thalach, exang | sex, restecg, age, trestbps, heartdisease)
# (fbs _|_ chol | sex, restecg, thalach, exang, heartdisease)
# (fbs _|_ chol | sex, restecg, thalach, trestbps, heartdisease)
# (fbs _|_ chol, thalach | sex, restecg, exang, trestbps, heartdisease)
# (fbs _|_ chol, restecg | sex, age, thalach, exang, heartdisease)
# (fbs _|_ chol, restecg, exang | sex, age, thalach, trestbps, heartdisease)
# (fbs _|_ restecg, chol, thalach | sex, age, exang, trestbps, heartdisease)
# (fbs _|_ chol, restecg | sex, thalach, exang, trestbps, heartdisease)
# (fbs _|_ exang, sex | chol, restecg, age, thalach, trestbps)
# (fbs _|_ sex | chol, restecg, age, exang, trestbps)
# (fbs _|_ thalach | chol, restecg, age, exang, heartdisease)
# (fbs _|_ thalach, exang, sex | chol, restecg, age, trestbps, heartdisease)
# (fbs _|_ thalach | chol, restecg, exang, trestbps, heartdisease)
# (fbs _|_ sex | chol, age, thalach, exang, trestbps)
# (fbs _|_ restecg | chol, age, thalach, exang, heartdisease)
# (fbs _|_ restecg, exang, sex | chol, age, thalach, trestbps, heartdisease)
# (fbs _|_ restecg, thalach, sex | chol, age, exang, trestbps, heartdisease)
# (fbs _|_ restecg | chol, thalach, exang, trestbps, heartdisease)
# (fbs _|_ sex | restecg, age, thalach, exang, trestbps)
# (fbs _|_ chol | restecg, age, thalach, exang, heartdisease)
# (fbs _|_ chol, exang, sex | restecg, age, thalach, trestbps, heartdisease)
# (fbs _|_ chol, thalach, sex | restecg, age, exang, trestbps, heartdisease)
# (fbs _|_ chol | restecg, thalach, exang, trestbps, heartdisease)
# (fbs _|_ chol, restecg, sex | age, thalach, exang, trestbps, heartdisease)
# (fbs _|_ exang | sex, chol, restecg, age, thalach, trestbps)
# (fbs _|_ thalach | sex, chol, restecg, age, exang, heartdisease)
# (fbs _|_ thalach, exang | sex, chol, restecg, age, trestbps, heartdisease)
# (fbs _|_ thalach | sex, chol, restecg, exang, trestbps, heartdisease)
# (fbs _|_ restecg | sex, chol, age, thalach, exang, heartdisease)
# (fbs _|_ restecg, exang | sex, chol, age, thalach, trestbps, heartdisease)
# (fbs _|_ restecg, thalach | sex, chol, age, exang, trestbps, heartdisease)
# (fbs _|_ restecg | sex, chol, thalach, exang, trestbps, heartdisease)
# (fbs _|_ chol | sex, restecg, age, thalach, exang, heartdisease)
# (fbs _|_ chol, exang | sex, restecg, age, thalach, trestbps, heartdisease)
# (fbs _|_ chol, thalach | sex, restecg, age, exang, trestbps, heartdisease)
# (fbs _|_ chol | sex, restecg, thalach, exang, trestbps, heartdisease)
# (fbs _|_ chol, restecg | sex, age, thalach, exang, trestbps, heartdisease)
# (fbs _|_ sex | chol, restecg, age, thalach, exang, trestbps)
# (fbs _|_ exang, sex | chol, restecg, age, thalach, trestbps, heartdisease)
# (fbs _|_ thalach, sex | chol, restecg, age, exang, trestbps, heartdisease)
# (fbs _|_ restecg, sex | chol, age, thalach, exang, trestbps, heartdisease)
# (fbs _|_ chol, sex | restecg, age, thalach, exang, trestbps, heartdisease)
# (fbs _|_ exang | sex, chol, restecg, age, thalach, trestbps, heartdisease)
# (fbs _|_ thalach | sex, chol, restecg, age, exang, trestbps, heartdisease)
# (fbs _|_ restecg | sex, chol, age, thalach, exang, trestbps, heartdisease)
# (fbs _|_ chol | sex, restecg, age, thalach, exang, trestbps, heartdisease)
# (fbs _|_ sex | chol, restecg, age, thalach, exang, trestbps, heartdisease)
# (sex _|_ fbs, exang, age)
# (sex _|_ fbs, exang | age)
# (sex _|_ exang, age | fbs)
# (sex _|_ fbs, age | exang)
# (sex _|_ thalach, chol, restecg | heartdisease)
# (sex _|_ thalach, restecg | chol, heartdisease)
# (sex _|_ chol, thalach | restecg, heartdisease)
# (sex _|_ exang | fbs, age)
# (sex _|_ fbs | exang, age)
# (sex _|_ fbs, thalach, chol, restecg, heartdisease | trestbps, age)
# (sex _|_ thalach, chol, restecg | heartdisease, age)
# (sex _|_ age | fbs, exang)
# (sex _|_ thalach, chol, restecg, heartdisease | trestbps, fbs)
# (sex _|_ thalach, chol, restecg | fbs, heartdisease)
# (sex _|_ chol, restecg | thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | exang, heartdisease)
# (sex _|_ thalach, chol, restecg | trestbps, heartdisease)
# (sex _|_ thalach | chol, restecg, heartdisease)
# (sex _|_ thalach, fbs, restecg, heartdisease | trestbps, chol, age)
# (sex _|_ thalach, restecg | chol, heartdisease, age)
# (sex _|_ thalach, restecg, heartdisease | fbs, chol, trestbps)
# (sex _|_ thalach, restecg | fbs, chol, heartdisease)
# (sex _|_ restecg | chol, thalach, heartdisease)
# (sex _|_ thalach, restecg | chol, exang, heartdisease)
# (sex _|_ thalach, restecg | trestbps, chol, heartdisease)
# (sex _|_ fbs, chol, thalach, heartdisease | trestbps, restecg, age)
# (sex _|_ chol, thalach | restecg, heartdisease, age)
# (sex _|_ chol, thalach, heartdisease | trestbps, fbs, restecg)
# (sex _|_ chol, thalach | fbs, restecg, heartdisease)
# (sex _|_ chol | thalach, restecg, heartdisease)
# (sex _|_ chol, thalach | restecg, exang, heartdisease)
# (sex _|_ chol, thalach | trestbps, restecg, heartdisease)
# (sex _|_ thalach, chol, restecg, heartdisease | trestbps, fbs, age)
# (sex _|_ thalach, chol, restecg | fbs, heartdisease, age)
# (sex _|_ fbs, chol, restecg, heartdisease | trestbps, thalach, age)
# (sex _|_ chol, restecg | thalach, heartdisease, age)
# (sex _|_ fbs, thalach, chol, restecg, heartdisease | trestbps, exang, age)
# (sex _|_ thalach, chol, restecg | exang, heartdisease, age)
# (sex _|_ thalach, fbs, chol, restecg | trestbps, heartdisease, age)
# (sex _|_ chol, restecg, heartdisease | trestbps, fbs, thalach)
# (sex _|_ chol, restecg | fbs, thalach, heartdisease)
# (sex _|_ thalach, chol, restecg, heartdisease | trestbps, fbs, exang)
# (sex _|_ thalach, chol, restecg | fbs, exang, heartdisease)
# (sex _|_ thalach, chol, restecg | trestbps, fbs, heartdisease)
# (sex _|_ chol, restecg | thalach, exang, heartdisease)
# (sex _|_ chol, restecg | trestbps, thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | trestbps, exang, heartdisease)
# (sex _|_ fbs, thalach, heartdisease | trestbps, chol, restecg, age)
# (sex _|_ thalach | chol, restecg, heartdisease, age)
# (sex _|_ thalach, heartdisease | fbs, chol, restecg, trestbps)
# (sex _|_ thalach | fbs, chol, restecg, heartdisease)
# (sex _|_ thalach | chol, restecg, exang, heartdisease)
# (sex _|_ thalach | trestbps, chol, restecg, heartdisease)
# (sex _|_ restecg, thalach, heartdisease | fbs, chol, trestbps, age)
# (sex _|_ restecg, thalach | fbs, chol, heartdisease, age)
# (sex _|_ fbs, restecg, heartdisease | trestbps, chol, thalach, age)
# (sex _|_ restecg | chol, thalach, heartdisease, age)
# (sex _|_ restecg, fbs, thalach, heartdisease | trestbps, chol, exang, age)
# (sex _|_ restecg, thalach | chol, exang, heartdisease, age)
# (sex _|_ restecg, fbs, thalach | trestbps, chol, heartdisease, age)
# (sex _|_ restecg, heartdisease | fbs, chol, thalach, trestbps)
# (sex _|_ restecg | fbs, chol, thalach, heartdisease)
# (sex _|_ restecg, thalach, heartdisease | fbs, chol, trestbps, exang)
# (sex _|_ restecg, thalach | fbs, chol, exang, heartdisease)
# (sex _|_ restecg, thalach | fbs, chol, trestbps, heartdisease)
# (sex _|_ restecg | chol, thalach, exang, heartdisease)
# (sex _|_ restecg | trestbps, chol, thalach, heartdisease)
# (sex _|_ restecg, thalach | trestbps, chol, exang, heartdisease)
# (sex _|_ chol, thalach, heartdisease | trestbps, fbs, restecg, age)
# (sex _|_ chol, thalach | fbs, restecg, heartdisease, age)
# (sex _|_ fbs, chol, heartdisease | thalach, trestbps, restecg, age)
# (sex _|_ chol | thalach, restecg, heartdisease, age)
# (sex _|_ thalach, fbs, chol, heartdisease | trestbps, restecg, exang, age)
# (sex _|_ chol, thalach | restecg, exang, heartdisease, age)
# (sex _|_ thalach, fbs, chol | trestbps, restecg, heartdisease, age)
# (sex _|_ chol, heartdisease | thalach, trestbps, fbs, restecg)
# (sex _|_ chol | thalach, fbs, restecg, heartdisease)
# (sex _|_ chol, thalach, heartdisease | trestbps, fbs, restecg, exang)
# (sex _|_ chol, thalach | fbs, restecg, exang, heartdisease)
# (sex _|_ chol, thalach | trestbps, fbs, restecg, heartdisease)
# (sex _|_ chol | thalach, restecg, exang, heartdisease)
# (sex _|_ chol | thalach, trestbps, restecg, heartdisease)
# (sex _|_ chol, thalach | trestbps, restecg, exang, heartdisease)
# (sex _|_ chol, restecg, heartdisease | trestbps, fbs, thalach, age)
# (sex _|_ chol, restecg | fbs, thalach, heartdisease, age)
# (sex _|_ restecg, chol, thalach, heartdisease | trestbps, fbs, exang, age)
# (sex _|_ restecg, chol, thalach | fbs, exang, heartdisease, age)
# (sex _|_ restecg, chol, thalach | trestbps, fbs, heartdisease, age)
# (sex _|_ restecg, fbs, chol, heartdisease | trestbps, thalach, exang, age)
# (sex _|_ chol, restecg | thalach, exang, heartdisease, age)
# (sex _|_ restecg, fbs, chol | trestbps, thalach, heartdisease, age)
# (sex _|_ chol, fbs, thalach, restecg | trestbps, exang, heartdisease, age)
# (sex _|_ chol, restecg, heartdisease | trestbps, fbs, thalach, exang)
# (sex _|_ chol, restecg | fbs, thalach, exang, heartdisease)
# (sex _|_ chol, restecg | trestbps, fbs, thalach, heartdisease)
# (sex _|_ restecg, chol, thalach | trestbps, fbs, exang, heartdisease)
# (sex _|_ chol, restecg | trestbps, thalach, exang, heartdisease)
# (sex _|_ thalach, heartdisease | chol, restecg, age, fbs, trestbps)
# (sex _|_ thalach | chol, restecg, age, fbs, heartdisease)
# (sex _|_ fbs, heartdisease | chol, restecg, age, thalach, trestbps)
# (sex _|_ fbs, thalach, heartdisease | chol, restecg, age, exang, trestbps)
# (sex _|_ thalach | chol, restecg, age, exang, heartdisease)
# (sex _|_ fbs, thalach | chol, restecg, age, trestbps, heartdisease)
# (sex _|_ heartdisease | chol, restecg, fbs, thalach, trestbps)
# (sex _|_ thalach, heartdisease | chol, restecg, fbs, exang, trestbps)
# (sex _|_ thalach | chol, restecg, fbs, exang, heartdisease)
# (sex _|_ thalach | chol, restecg, fbs, trestbps, heartdisease)
# (sex _|_ thalach | chol, restecg, exang, trestbps, heartdisease)
# (sex _|_ restecg, heartdisease | chol, age, fbs, thalach, trestbps)
# (sex _|_ restecg | chol, age, fbs, thalach, heartdisease)
# (sex _|_ restecg, thalach, heartdisease | chol, age, fbs, exang, trestbps)
# (sex _|_ restecg, thalach | chol, age, fbs, exang, heartdisease)
# (sex _|_ restecg, thalach | chol, age, fbs, trestbps, heartdisease)
# (sex _|_ fbs, restecg, heartdisease | chol, age, thalach, exang, trestbps)
# (sex _|_ restecg | chol, age, thalach, exang, heartdisease)
# (sex _|_ fbs, restecg | chol, age, thalach, trestbps, heartdisease)
# (sex _|_ restecg, fbs, thalach | chol, age, exang, trestbps, heartdisease)
# (sex _|_ restecg, heartdisease | chol, fbs, thalach, exang, trestbps)
# (sex _|_ restecg | chol, fbs, thalach, exang, heartdisease)
# (sex _|_ restecg | chol, fbs, thalach, trestbps, heartdisease)
# (sex _|_ restecg, thalach | chol, fbs, exang, trestbps, heartdisease)
# (sex _|_ restecg | chol, thalach, exang, trestbps, heartdisease)
# (sex _|_ chol, heartdisease | restecg, age, fbs, thalach, trestbps)
# (sex _|_ chol | restecg, age, fbs, thalach, heartdisease)
# (sex _|_ chol, thalach, heartdisease | restecg, age, fbs, exang, trestbps)
# (sex _|_ chol, thalach | restecg, age, fbs, exang, heartdisease)
# (sex _|_ chol, thalach | restecg, age, fbs, trestbps, heartdisease)
# (sex _|_ fbs, chol, heartdisease | restecg, age, thalach, exang, trestbps)
# (sex _|_ chol | restecg, age, thalach, exang, heartdisease)
# (sex _|_ fbs, chol | restecg, age, thalach, trestbps, heartdisease)
# (sex _|_ thalach, fbs, chol | restecg, age, exang, trestbps, heartdisease)
# (sex _|_ chol, heartdisease | restecg, fbs, thalach, exang, trestbps)
# (sex _|_ chol | restecg, fbs, thalach, exang, heartdisease)
# (sex _|_ chol | restecg, fbs, thalach, trestbps, heartdisease)
# (sex _|_ chol, thalach | restecg, fbs, exang, trestbps, heartdisease)
# (sex _|_ chol | restecg, thalach, exang, trestbps, heartdisease)
# (sex _|_ chol, restecg, heartdisease | age, fbs, thalach, exang, trestbps)
# (sex _|_ chol, restecg | age, fbs, thalach, exang, heartdisease)
# (sex _|_ chol, restecg | age, fbs, thalach, trestbps, heartdisease)
# (sex _|_ restecg, chol, thalach | age, fbs, exang, trestbps, heartdisease)
# (sex _|_ restecg, fbs, chol | age, thalach, exang, trestbps, heartdisease)
# (sex _|_ chol, restecg | fbs, thalach, exang, trestbps, heartdisease)
# (sex _|_ heartdisease | chol, restecg, age, fbs, thalach, trestbps)
# (sex _|_ thalach, heartdisease | chol, restecg, age, fbs, exang, trestbps)
# (sex _|_ thalach | chol, restecg, age, fbs, exang, heartdisease)
# (sex _|_ thalach | chol, restecg, age, fbs, trestbps, heartdisease)
# (sex _|_ fbs, heartdisease | chol, restecg, age, thalach, exang, trestbps)
# (sex _|_ fbs | chol, restecg, age, thalach, trestbps, heartdisease)
# (sex _|_ fbs, thalach | chol, restecg, age, exang, trestbps, heartdisease)
# (sex _|_ heartdisease | chol, restecg, fbs, thalach, exang, trestbps)
# (sex _|_ thalach | chol, restecg, fbs, exang, trestbps, heartdisease)
# (sex _|_ restecg, heartdisease | chol, age, fbs, thalach, exang, trestbps)
# (sex _|_ restecg | chol, age, fbs, thalach, exang, heartdisease)
# (sex _|_ restecg | chol, age, fbs, thalach, trestbps, heartdisease)
# (sex _|_ restecg, thalach | chol, age, fbs, exang, trestbps, heartdisease)
# (sex _|_ fbs, restecg | chol, age, thalach, exang, trestbps, heartdisease)
# (sex _|_ restecg | chol, fbs, thalach, exang, trestbps, heartdisease)
# (sex _|_ chol, heartdisease | restecg, age, fbs, thalach, exang, trestbps)
# (sex _|_ chol | restecg, age, fbs, thalach, exang, heartdisease)
# (sex _|_ chol | restecg, age, fbs, thalach, trestbps, heartdisease)
# (sex _|_ chol, thalach | restecg, age, fbs, exang, trestbps, heartdisease)
# (sex _|_ fbs, chol | restecg, age, thalach, exang, trestbps, heartdisease)
# (sex _|_ chol | restecg, fbs, thalach, exang, trestbps, heartdisease)
# (sex _|_ chol, restecg | age, fbs, thalach, exang, trestbps, heartdisease)
# (sex _|_ heartdisease | chol, restecg, age, fbs, thalach, exang, trestbps)
# (sex _|_ thalach | chol, restecg, age, fbs, exang, trestbps, heartdisease)
# (sex _|_ fbs | chol, restecg, age, thalach, exang, trestbps, heartdisease)
# (sex _|_ restecg | chol, age, fbs, thalach, exang, trestbps, heartdisease)
# (sex _|_ chol | restecg, age, fbs, thalach, exang, trestbps, heartdisease)
# (exang _|_ fbs, sex, age)
# (exang _|_ fbs, age | sex)
# (exang _|_ fbs, sex | age)
# (exang _|_ sex, age | fbs)
# (exang _|_ thalach, chol, restecg | heartdisease)
# (exang _|_ fbs | sex, age)
# (exang _|_ age | fbs, sex)
# (exang _|_ thalach, chol, restecg | heartdisease, sex)
# (exang _|_ thalach, restecg | chol, heartdisease)
# (exang _|_ chol, thalach | restecg, heartdisease)
# (exang _|_ sex | fbs, age)
# (exang _|_ fbs, thalach, chol, restecg, heartdisease | trestbps, age)
# (exang _|_ thalach, chol, restecg | heartdisease, age)
# (exang _|_ thalach, chol, restecg, heartdisease | trestbps, fbs)
# (exang _|_ thalach, chol, restecg | fbs, heartdisease)
# (exang _|_ chol, restecg | thalach, heartdisease)
# (exang _|_ thalach, chol, restecg | trestbps, heartdisease)
# (exang _|_ thalach, restecg | chol, heartdisease, sex)
# (exang _|_ chol, thalach | restecg, heartdisease, sex)
# (exang _|_ fbs, thalach, chol, restecg, heartdisease | trestbps, sex, age)
# (exang _|_ thalach, chol, restecg | heartdisease, sex, age)
# (exang _|_ thalach, chol, restecg, heartdisease | trestbps, fbs, sex)
# (exang _|_ thalach, chol, restecg | fbs, heartdisease, sex)
# (exang _|_ chol, restecg | thalach, heartdisease, sex)
# (exang _|_ thalach, chol, restecg | trestbps, heartdisease, sex)
# (exang _|_ thalach | chol, restecg, heartdisease)
# (exang _|_ thalach, fbs, restecg, heartdisease | trestbps, chol, age)
# (exang _|_ thalach, restecg | chol, heartdisease, age)
# (exang _|_ thalach, restecg, heartdisease | fbs, chol, trestbps)
# (exang _|_ thalach, restecg | fbs, chol, heartdisease)
# (exang _|_ restecg | chol, thalach, heartdisease)
# (exang _|_ thalach, restecg | trestbps, chol, heartdisease)
# (exang _|_ fbs, chol, thalach, heartdisease | trestbps, restecg, age)
# (exang _|_ chol, thalach | restecg, heartdisease, age)
# (exang _|_ chol, thalach, heartdisease | trestbps, fbs, restecg)
# (exang _|_ chol, thalach | fbs, restecg, heartdisease)
# (exang _|_ chol | thalach, restecg, heartdisease)
# (exang _|_ chol, thalach | trestbps, restecg, heartdisease)
# (exang _|_ thalach, chol, restecg, heartdisease | trestbps, fbs, age)
# (exang _|_ thalach, chol, restecg | fbs, heartdisease, age)
# (exang _|_ fbs, chol, restecg, heartdisease | trestbps, thalach, age)
# (exang _|_ chol, restecg | thalach, heartdisease, age)
# (exang _|_ thalach, fbs, chol, restecg | trestbps, heartdisease, age)
# (exang _|_ chol, restecg, heartdisease | trestbps, fbs, thalach)
# (exang _|_ chol, restecg | fbs, thalach, heartdisease)
# (exang _|_ thalach, chol, restecg | trestbps, fbs, heartdisease)
# (exang _|_ chol, restecg | trestbps, thalach, heartdisease)
# (exang _|_ thalach | chol, restecg, heartdisease, sex)
# (exang _|_ restecg, fbs, thalach, heartdisease | trestbps, chol, sex, age)
# (exang _|_ restecg, thalach | chol, heartdisease, sex, age)
# (exang _|_ restecg, thalach, heartdisease | fbs, chol, trestbps, sex)
# (exang _|_ restecg, thalach | fbs, chol, heartdisease, sex)
# (exang _|_ restecg | chol, thalach, heartdisease, sex)
# (exang _|_ restecg, thalach | trestbps, chol, heartdisease, sex)
# (exang _|_ thalach, fbs, chol, heartdisease | trestbps, restecg, sex, age)
# (exang _|_ chol, thalach | restecg, heartdisease, sex, age)
# (exang _|_ chol, thalach, heartdisease | trestbps, fbs, restecg, sex)
# (exang _|_ chol, thalach | fbs, restecg, heartdisease, sex)
# (exang _|_ chol | thalach, restecg, heartdisease, sex)
# (exang _|_ chol, thalach | trestbps, restecg, heartdisease, sex)
# (exang _|_ restecg, chol, thalach, heartdisease | trestbps, fbs, sex, age)
# (exang _|_ restecg, chol, thalach | fbs, heartdisease, sex, age)
# (exang _|_ restecg, fbs, chol, heartdisease | trestbps, thalach, sex, age)
# (exang _|_ chol, restecg | thalach, heartdisease, sex, age)
# (exang _|_ chol, fbs, thalach, restecg | trestbps, heartdisease, sex, age)
# (exang _|_ chol, restecg, heartdisease | trestbps, fbs, thalach, sex)
# (exang _|_ chol, restecg | fbs, thalach, heartdisease, sex)
# (exang _|_ restecg, chol, thalach | trestbps, fbs, heartdisease, sex)
# (exang _|_ chol, restecg | trestbps, thalach, heartdisease, sex)
# (exang _|_ fbs, thalach, heartdisease | trestbps, chol, restecg, age)
# (exang _|_ thalach | chol, restecg, heartdisease, age)
# (exang _|_ thalach, heartdisease | fbs, chol, restecg, trestbps)
# (exang _|_ thalach | fbs, chol, restecg, heartdisease)
# (exang _|_ thalach | trestbps, chol, restecg, heartdisease)
# (exang _|_ restecg, thalach, heartdisease | fbs, chol, trestbps, age)
# (exang _|_ restecg, thalach | fbs, chol, heartdisease, age)
# (exang _|_ fbs, restecg, heartdisease | trestbps, chol, thalach, age)
# (exang _|_ restecg | chol, thalach, heartdisease, age)
# (exang _|_ restecg, fbs, thalach | trestbps, chol, heartdisease, age)
# (exang _|_ restecg, heartdisease | fbs, chol, thalach, trestbps)
# (exang _|_ restecg | fbs, chol, thalach, heartdisease)
# (exang _|_ restecg, thalach | fbs, chol, trestbps, heartdisease)
# (exang _|_ restecg | trestbps, chol, thalach, heartdisease)
# (exang _|_ chol, thalach, heartdisease | trestbps, fbs, restecg, age)
# (exang _|_ chol, thalach | fbs, restecg, heartdisease, age)
# (exang _|_ fbs, chol, heartdisease | thalach, trestbps, restecg, age)
# (exang _|_ chol | thalach, restecg, heartdisease, age)
# (exang _|_ thalach, fbs, chol | trestbps, restecg, heartdisease, age)
# (exang _|_ chol, heartdisease | thalach, trestbps, fbs, restecg)
# (exang _|_ chol | thalach, fbs, restecg, heartdisease)
# (exang _|_ chol, thalach | trestbps, fbs, restecg, heartdisease)
# (exang _|_ chol | thalach, trestbps, restecg, heartdisease)
# (exang _|_ chol, restecg, heartdisease | trestbps, fbs, thalach, age)
# (exang _|_ chol, restecg | fbs, thalach, heartdisease, age)
# (exang _|_ restecg, chol, thalach | trestbps, fbs, heartdisease, age)
# (exang _|_ restecg, fbs, chol | trestbps, thalach, heartdisease, age)
# (exang _|_ chol, restecg | trestbps, fbs, thalach, heartdisease)
# (exang _|_ fbs, thalach, heartdisease | sex, chol, restecg, age, trestbps)
# (exang _|_ thalach | sex, chol, restecg, age, heartdisease)
# (exang _|_ thalach, heartdisease | sex, chol, restecg, fbs, trestbps)
# (exang _|_ thalach | sex, chol, restecg, fbs, heartdisease)
# (exang _|_ thalach | sex, chol, restecg, trestbps, heartdisease)
# (exang _|_ restecg, thalach, heartdisease | sex, chol, age, fbs, trestbps)
# (exang _|_ restecg, thalach | sex, chol, age, fbs, heartdisease)
# (exang _|_ fbs, restecg, heartdisease | sex, chol, age, thalach, trestbps)
# (exang _|_ restecg | sex, chol, age, thalach, heartdisease)
# (exang _|_ restecg, fbs, thalach | sex, chol, age, trestbps, heartdisease)
# (exang _|_ restecg, heartdisease | sex, chol, fbs, thalach, trestbps)
# (exang _|_ restecg | sex, chol, fbs, thalach, heartdisease)
# (exang _|_ restecg, thalach | sex, chol, fbs, trestbps, heartdisease)
# (exang _|_ restecg | sex, chol, thalach, trestbps, heartdisease)
# (exang _|_ chol, thalach, heartdisease | sex, restecg, age, fbs, trestbps)
# (exang _|_ chol, thalach | sex, restecg, age, fbs, heartdisease)
# (exang _|_ fbs, chol, heartdisease | sex, restecg, age, thalach, trestbps)
# (exang _|_ chol | sex, restecg, age, thalach, heartdisease)
# (exang _|_ thalach, fbs, chol | sex, restecg, age, trestbps, heartdisease)
# (exang _|_ chol, heartdisease | sex, restecg, fbs, thalach, trestbps)
# (exang _|_ chol | sex, restecg, fbs, thalach, heartdisease)
# (exang _|_ chol, thalach | sex, restecg, fbs, trestbps, heartdisease)
# (exang _|_ chol | sex, restecg, thalach, trestbps, heartdisease)
# (exang _|_ chol, restecg, heartdisease | sex, age, fbs, thalach, trestbps)
# (exang _|_ chol, restecg | sex, age, fbs, thalach, heartdisease)
# (exang _|_ restecg, chol, thalach | sex, age, fbs, trestbps, heartdisease)
# (exang _|_ restecg, fbs, chol | sex, age, thalach, trestbps, heartdisease)
# (exang _|_ chol, restecg | sex, fbs, thalach, trestbps, heartdisease)
# (exang _|_ thalach, heartdisease | chol, restecg, age, fbs, trestbps)
# (exang _|_ thalach | chol, restecg, age, fbs, heartdisease)
# (exang _|_ fbs, heartdisease | chol, restecg, age, thalach, trestbps)
# (exang _|_ fbs, thalach | chol, restecg, age, trestbps, heartdisease)
# (exang _|_ heartdisease | chol, restecg, fbs, thalach, trestbps)
# (exang _|_ thalach | chol, restecg, fbs, trestbps, heartdisease)
# (exang _|_ restecg, heartdisease | chol, age, fbs, thalach, trestbps)
# (exang _|_ restecg | chol, age, fbs, thalach, heartdisease)
# (exang _|_ restecg, thalach | chol, age, fbs, trestbps, heartdisease)
# (exang _|_ fbs, restecg | chol, age, thalach, trestbps, heartdisease)
# (exang _|_ restecg | chol, fbs, thalach, trestbps, heartdisease)
# (exang _|_ chol, heartdisease | restecg, age, fbs, thalach, trestbps)
# (exang _|_ chol | restecg, age, fbs, thalach, heartdisease)
# (exang _|_ chol, thalach | restecg, age, fbs, trestbps, heartdisease)
# (exang _|_ fbs, chol | restecg, age, thalach, trestbps, heartdisease)
# (exang _|_ chol | restecg, fbs, thalach, trestbps, heartdisease)
# (exang _|_ chol, restecg | age, fbs, thalach, trestbps, heartdisease)
# (exang _|_ thalach, heartdisease | sex, chol, restecg, age, fbs, trestbps)
# (exang _|_ thalach | sex, chol, restecg, age, fbs, heartdisease)
# (exang _|_ fbs, heartdisease | sex, chol, restecg, age, thalach, trestbps)
# (exang _|_ fbs, thalach | sex, chol, restecg, age, trestbps, heartdisease)
# (exang _|_ heartdisease | sex, chol, restecg, fbs, thalach, trestbps)
# (exang _|_ thalach | sex, chol, restecg, fbs, trestbps, heartdisease)
# (exang _|_ restecg, heartdisease | sex, chol, age, fbs, thalach, trestbps)
# (exang _|_ restecg | sex, chol, age, fbs, thalach, heartdisease)
# (exang _|_ restecg, thalach | sex, chol, age, fbs, trestbps, heartdisease)
# (exang _|_ fbs, restecg | sex, chol, age, thalach, trestbps, heartdisease)
# (exang _|_ restecg | sex, chol, fbs, thalach, trestbps, heartdisease)
# (exang _|_ chol, heartdisease | sex, restecg, age, fbs, thalach, trestbps)
# (exang _|_ chol | sex, restecg, age, fbs, thalach, heartdisease)
# (exang _|_ chol, thalach | sex, restecg, age, fbs, trestbps, heartdisease)
# (exang _|_ fbs, chol | sex, restecg, age, thalach, trestbps, heartdisease)
# (exang _|_ chol | sex, restecg, fbs, thalach, trestbps, heartdisease)
# (exang _|_ chol, restecg | sex, age, fbs, thalach, trestbps, heartdisease)
# (exang _|_ heartdisease | chol, restecg, age, fbs, thalach, trestbps)
# (exang _|_ thalach | chol, restecg, age, fbs, trestbps, heartdisease)
# (exang _|_ fbs | chol, restecg, age, thalach, trestbps, heartdisease)
# (exang _|_ restecg | chol, age, fbs, thalach, trestbps, heartdisease)
# (exang _|_ chol | restecg, age, fbs, thalach, trestbps, heartdisease)
# (exang _|_ heartdisease | sex, chol, restecg, age, fbs, thalach, trestbps)
# (exang _|_ thalach | sex, chol, restecg, age, fbs, trestbps, heartdisease)
# (exang _|_ fbs | sex, chol, restecg, age, thalach, trestbps, heartdisease)
# (exang _|_ restecg | sex, chol, age, fbs, thalach, trestbps, heartdisease)
# (exang _|_ chol | sex, restecg, age, fbs, thalach, trestbps, heartdisease)
# (heartdisease _|_ exang, sex | trestbps, age)
# (heartdisease _|_ exang, sex, age | trestbps, fbs)
# (heartdisease _|_ exang | trestbps, sex, age)
# (heartdisease _|_ exang, age | trestbps, fbs, sex)
# (heartdisease _|_ exang, sex | trestbps, chol, age)
# (heartdisease _|_ exang, sex, age | fbs, chol, trestbps)
# (heartdisease _|_ exang, sex | trestbps, restecg, age)
# (heartdisease _|_ exang, sex, age | trestbps, fbs, restecg)
# (heartdisease _|_ exang, sex | trestbps, fbs, age)
# (heartdisease _|_ exang, sex | trestbps, thalach, age)
# (heartdisease _|_ sex | trestbps, exang, age)
# (heartdisease _|_ exang, sex, age | trestbps, fbs, thalach)
# (heartdisease _|_ sex, age | trestbps, fbs, exang)
# (heartdisease _|_ exang | trestbps, chol, sex, age)
# (heartdisease _|_ exang, age | fbs, chol, trestbps, sex)
# (heartdisease _|_ exang | trestbps, restecg, sex, age)
# (heartdisease _|_ exang, age | trestbps, fbs, restecg, sex)
# (heartdisease _|_ exang | trestbps, fbs, sex, age)
# (heartdisease _|_ exang | trestbps, thalach, sex, age)
# (heartdisease _|_ exang, age | trestbps, fbs, thalach, sex)
# (heartdisease _|_ age | trestbps, fbs, exang, sex)
# (heartdisease _|_ exang, sex | trestbps, chol, restecg, age)
# (heartdisease _|_ exang, sex, age | fbs, chol, restecg, trestbps)
# (heartdisease _|_ exang, sex | fbs, chol, trestbps, age)
# ...
# (thalach _|_ trestbps, fbs, chol | sex, restecg, age, exang, heartdisease)
# (thalach _|_ fbs, chol, exang | sex, restecg, age, trestbps, heartdisease)
# (thalach _|_ age | sex, restecg, fbs, exang, trestbps)
# (thalach _|_ trestbps, chol, age | sex, restecg, fbs, exang, heartdisease)
# (thalach _|_ chol, exang, age | sex, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, chol, age | sex, restecg, exang, trestbps, heartdisease)
# (thalach _|_ trestbps, chol, restecg | sex, age, fbs, exang, heartdisease)
# (thalach _|_ chol, restecg, exang | sex, age, fbs, trestbps, heartdisease)
# (thalach _|_ restecg, fbs, chol | sex, age, exang, trestbps, heartdisease)
# (thalach _|_ chol, restecg, age | sex, fbs, exang, trestbps, heartdisease)
# (thalach _|_ exang, sex | chol, restecg, age, fbs, trestbps)
# (thalach _|_ trestbps, exang, sex | chol, restecg, age, fbs, heartdisease)
# (thalach _|_ sex | chol, restecg, age, exang, trestbps)
# (thalach _|_ trestbps, fbs, sex | chol, restecg, age, exang, heartdisease)
# (thalach _|_ fbs, exang, sex | chol, restecg, age, trestbps, heartdisease)
# (thalach _|_ sex, age | chol, restecg, fbs, exang, trestbps)
# (thalach _|_ trestbps, sex, age | chol, restecg, fbs, exang, heartdisease)
# (thalach _|_ exang, sex, age | chol, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, sex, age | chol, restecg, exang, trestbps, heartdisease)
# (thalach _|_ sex | chol, age, fbs, exang, trestbps)
# (thalach _|_ trestbps, restecg, sex | chol, age, fbs, exang, heartdisease)
# (thalach _|_ restecg, exang, sex | chol, age, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, restecg, sex | chol, age, exang, trestbps, heartdisease)
# (thalach _|_ restecg, sex, age | chol, fbs, exang, trestbps, heartdisease)
# (thalach _|_ sex | restecg, age, fbs, exang, trestbps)
# (thalach _|_ trestbps, chol, sex | restecg, age, fbs, exang, heartdisease)
# (thalach _|_ chol, exang, sex | restecg, age, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, chol, sex | restecg, age, exang, trestbps, heartdisease)
# (thalach _|_ chol, sex, age | restecg, fbs, exang, trestbps, heartdisease)
# (thalach _|_ chol, restecg, sex | age, fbs, exang, trestbps, heartdisease)
# (thalach _|_ exang | sex, chol, restecg, age, fbs, trestbps)
# (thalach _|_ trestbps, exang | sex, chol, restecg, age, fbs, heartdisease)
# (thalach _|_ trestbps, fbs | sex, chol, restecg, age, exang, heartdisease)
# (thalach _|_ fbs, exang | sex, chol, restecg, age, trestbps, heartdisease)
# (thalach _|_ age | sex, chol, restecg, fbs, exang, trestbps)
# (thalach _|_ trestbps, age | sex, chol, restecg, fbs, exang, heartdisease)
# (thalach _|_ exang, age | sex, chol, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, age | sex, chol, restecg, exang, trestbps, heartdisease)
# (thalach _|_ trestbps, restecg | sex, chol, age, fbs, exang, heartdisease)
# (thalach _|_ restecg, exang | sex, chol, age, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, restecg | sex, chol, age, exang, trestbps, heartdisease)
# (thalach _|_ restecg, age | sex, chol, fbs, exang, trestbps, heartdisease)
# (thalach _|_ trestbps, chol | sex, restecg, age, fbs, exang, heartdisease)
# (thalach _|_ chol, exang | sex, restecg, age, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, chol | sex, restecg, age, exang, trestbps, heartdisease)
# (thalach _|_ chol, age | sex, restecg, fbs, exang, trestbps, heartdisease)
# (thalach _|_ chol, restecg | sex, age, fbs, exang, trestbps, heartdisease)
# (thalach _|_ sex | chol, restecg, age, fbs, exang, trestbps)
# (thalach _|_ trestbps, sex | chol, restecg, age, fbs, exang, heartdisease)
# (thalach _|_ exang, sex | chol, restecg, age, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, sex | chol, restecg, age, exang, trestbps, heartdisease)
# (thalach _|_ sex, age | chol, restecg, fbs, exang, trestbps, heartdisease)
# (thalach _|_ restecg, sex | chol, age, fbs, exang, trestbps, heartdisease)
# (thalach _|_ chol, sex | restecg, age, fbs, exang, trestbps, heartdisease)
# (thalach _|_ trestbps | sex, chol, restecg, age, fbs, exang, heartdisease)
# (thalach _|_ exang | sex, chol, restecg, age, fbs, trestbps, heartdisease)
# (thalach _|_ fbs | sex, chol, restecg, age, exang, trestbps, heartdisease)
# (thalach _|_ age | sex, chol, restecg, fbs, exang, trestbps, heartdisease)
# (thalach _|_ restecg | sex, chol, age, fbs, exang, trestbps, heartdisease)
# (thalach _|_ chol | sex, restecg, age, fbs, exang, trestbps, heartdisease)
# (thalach _|_ sex | chol, restecg, age, fbs, exang, trestbps, heartdisease)
# (chol _|_ fbs, thalach, exang, sex, trestbps, restecg, age | heartdisease)
# (chol _|_ fbs, thalach, exang, trestbps, restecg, age | heartdisease, sex)
# (chol _|_ fbs, thalach, exang, sex, trestbps, age | restecg, heartdisease)
# (chol _|_ exang, sex | trestbps, age)
# (chol _|_ fbs, thalach, exang, sex, trestbps, restecg | heartdisease, age)
# (chol _|_ exang, sex, age | trestbps, fbs)
# (chol _|_ thalach, exang, sex, trestbps, restecg, age | fbs, heartdisease)
# (chol _|_ fbs, exang, sex, trestbps, restecg, age | thalach, heartdisease)
# (chol _|_ fbs, thalach, sex, trestbps, restecg, age | exang, heartdisease)
# (chol _|_ fbs, thalach, exang, sex, restecg, age | trestbps, heartdisease)
# (chol _|_ fbs, thalach, exang, trestbps, age | restecg, heartdisease, sex)
# (chol _|_ exang | trestbps, sex, age)
# (chol _|_ fbs, thalach, exang, trestbps, restecg | heartdisease, sex, age)
# (chol _|_ exang, age | trestbps, fbs, sex)
# (chol _|_ thalach, exang, trestbps, restecg, age | fbs, heartdisease, sex)
# (chol _|_ fbs, exang, trestbps, restecg, age | thalach, heartdisease, sex)
# (chol _|_ fbs, thalach, trestbps, restecg, age | heartdisease, exang, sex)
# (chol _|_ fbs, thalach, exang, restecg, age | trestbps, heartdisease, sex)
# (chol _|_ exang, sex | trestbps, restecg, age)
# (chol _|_ fbs, thalach, exang, sex, trestbps | restecg, heartdisease, age)
# (chol _|_ exang, sex, age | trestbps, fbs, restecg)
# (chol _|_ thalach, exang, sex, trestbps, age | fbs, restecg, heartdisease)
# (chol _|_ fbs, exang, sex, trestbps, age | thalach, restecg, heartdisease)
# (chol _|_ fbs, thalach, sex, trestbps, age | restecg, exang, heartdisease)
# (chol _|_ fbs, thalach, exang, sex, age | trestbps, restecg, heartdisease)
# (chol _|_ exang, sex | trestbps, fbs, age)
# (chol _|_ thalach, exang, sex, trestbps, restecg | fbs, heartdisease, age)
# (chol _|_ exang, sex | trestbps, thalach, age)
# (chol _|_ fbs, exang, sex, trestbps, restecg | thalach, heartdisease, age)
# (chol _|_ sex | trestbps, exang, age)
# (chol _|_ fbs, thalach, sex, trestbps, restecg | exang, heartdisease, age)
# (chol _|_ fbs, thalach, exang, sex, restecg | trestbps, heartdisease, age)
# (chol _|_ exang, sex, age | trestbps, fbs, thalach)
# (chol _|_ exang, sex, trestbps, restecg, age | fbs, thalach, heartdisease)
# (chol _|_ sex, age | trestbps, fbs, exang)
# (chol _|_ thalach, sex, trestbps, restecg, age | fbs, exang, heartdisease)
# (chol _|_ thalach, exang, sex, restecg, age | trestbps, fbs, heartdisease)
# (chol _|_ fbs, sex, trestbps, restecg, age | thalach, exang, heartdisease)
# (chol _|_ fbs, exang, sex, restecg, age | trestbps, thalach, heartdisease)
# (chol _|_ fbs, thalach, sex, restecg, age | trestbps, exang, heartdisease)
# (chol _|_ exang | trestbps, restecg, sex, age)
# (chol _|_ trestbps, fbs, thalach, exang | restecg, heartdisease, sex, age)
# (chol _|_ exang, age | trestbps, fbs, restecg, sex)
# (chol _|_ trestbps, thalach, exang, age | fbs, restecg, heartdisease, sex)
# (chol _|_ trestbps, fbs, exang, age | thalach, restecg, heartdisease, sex)
# (chol _|_ trestbps, fbs, thalach, age | heartdisease, restecg, exang, sex)
# (chol _|_ fbs, thalach, exang, age | trestbps, restecg, heartdisease, sex)
# (chol _|_ exang | trestbps, fbs, sex, age)
# (chol _|_ trestbps, thalach, exang, restecg | fbs, heartdisease, sex, age)
# (chol _|_ exang | trestbps, thalach, sex, age)
# (chol _|_ trestbps, fbs, restecg, exang | thalach, heartdisease, sex, age)
# (chol _|_ trestbps, fbs, thalach, restecg | heartdisease, exang, sex, age)
# (chol _|_ restecg, fbs, thalach, exang | trestbps, heartdisease, sex, age)
# (chol _|_ exang, age | trestbps, fbs, thalach, sex)
# (chol _|_ trestbps, restecg, exang, age | fbs, thalach, heartdisease, sex)
# (chol _|_ age | trestbps, fbs, exang, sex)
# (chol _|_ trestbps, thalach, age, restecg | fbs, heartdisease, exang, sex)
# (chol _|_ restecg, thalach, exang, age | trestbps, fbs, heartdisease, sex)
# (chol _|_ trestbps, fbs, restecg, age | heartdisease, thalach, exang, sex)
# (chol _|_ fbs, restecg, exang, age | trestbps, thalach, heartdisease, sex)
# (chol _|_ restecg, fbs, thalach, age | trestbps, heartdisease, exang, sex)
# (chol _|_ exang, sex | trestbps, fbs, restecg, age)
# (chol _|_ trestbps, thalach, exang, sex | fbs, restecg, heartdisease, age)
# (chol _|_ exang, sex | thalach, trestbps, restecg, age)
# (chol _|_ trestbps, fbs, exang, sex | thalach, restecg, heartdisease, age)
# (chol _|_ sex | trestbps, restecg, exang, age)
# (chol _|_ trestbps, fbs, thalach, sex | restecg, exang, heartdisease, age)
# (chol _|_ fbs, thalach, exang, sex | trestbps, restecg, heartdisease, age)
# (chol _|_ exang, sex, age | thalach, trestbps, fbs, restecg)
# (chol _|_ trestbps, exang, sex, age | thalach, fbs, restecg, heartdisease)
# (chol _|_ sex, age | trestbps, fbs, restecg, exang)
# (chol _|_ trestbps, thalach, sex, age | fbs, restecg, exang, heartdisease)
# (chol _|_ thalach, exang, sex, age | trestbps, fbs, restecg, heartdisease)
# (chol _|_ trestbps, fbs, sex, age | thalach, restecg, exang, heartdisease)
# (chol _|_ fbs, exang, sex, age | thalach, trestbps, restecg, heartdisease)
# (chol _|_ fbs, thalach, sex, age | trestbps, restecg, exang, heartdisease)
# (chol _|_ exang, sex | trestbps, fbs, thalach, age)
# (chol _|_ trestbps, restecg, exang, sex | fbs, thalach, heartdisease, age)
# (chol _|_ sex | trestbps, fbs, exang, age)
# (chol _|_ trestbps, thalach, sex, restecg | fbs, exang, heartdisease, age)
# (chol _|_ restecg, thalach, exang, sex | trestbps, fbs, heartdisease, age)
# (chol _|_ sex | trestbps, thalach, exang, age)
# (chol _|_ trestbps, fbs, restecg, sex | thalach, exang, heartdisease, age)
# (chol _|_ fbs, restecg, exang, sex | trestbps, thalach, heartdisease, age)
# (chol _|_ restecg, fbs, thalach, sex | trestbps, exang, heartdisease, age)
# (chol _|_ sex, age | trestbps, fbs, thalach, exang)
# (chol _|_ trestbps, restecg, sex, age | fbs, thalach, exang, heartdisease)
# (chol _|_ restecg, exang, sex, age | trestbps, fbs, thalach, heartdisease)
# (chol _|_ restecg, thalach, sex, age | trestbps, fbs, exang, heartdisease)
# (chol _|_ fbs, restecg, sex, age | trestbps, thalach, exang, heartdisease)
# (chol _|_ exang | sex, restecg, age, fbs, trestbps)
# (chol _|_ trestbps, thalach, exang | sex, restecg, age, fbs, heartdisease)
# (chol _|_ exang | sex, restecg, age, thalach, trestbps)
# (chol _|_ trestbps, fbs, exang | sex, restecg, age, thalach, heartdisease)
# (chol _|_ trestbps, fbs, thalach | sex, restecg, age, exang, heartdisease)
# (chol _|_ fbs, thalach, exang | sex, restecg, age, trestbps, heartdisease)
# (chol _|_ exang, age | sex, restecg, fbs, thalach, trestbps)
# (chol _|_ trestbps, exang, age | sex, restecg, fbs, thalach, heartdisease)
# (chol _|_ age | sex, restecg, fbs, exang, trestbps)
# (chol _|_ trestbps, thalach, age | sex, restecg, fbs, exang, heartdisease)
# (chol _|_ thalach, exang, age | sex, restecg, fbs, trestbps, heartdisease)
# (chol _|_ trestbps, fbs, age | sex, restecg, thalach, exang, heartdisease)
# (chol _|_ fbs, exang, age | sex, restecg, thalach, trestbps, heartdisease)
# (chol _|_ fbs, thalach, age | sex, restecg, exang, trestbps, heartdisease)
# (chol _|_ exang | sex, age, fbs, thalach, trestbps)
# (chol _|_ trestbps, restecg, exang | sex, age, fbs, thalach, heartdisease)
# (chol _|_ trestbps, thalach, restecg | sex, age, fbs, exang, heartdisease)
# (chol _|_ restecg, thalach, exang | sex, age, fbs, trestbps, heartdisease)
# (chol _|_ trestbps, fbs, restecg | sex, age, thalach, exang, heartdisease)
# (chol _|_ fbs, restecg, exang | sex, age, thalach, trestbps, heartdisease)
# (chol _|_ restecg, fbs, thalach | sex, age, exang, trestbps, heartdisease)
# (chol _|_ age | sex, fbs, thalach, exang, trestbps)
# (chol _|_ trestbps, restecg, age | sex, fbs, thalach, exang, heartdisease)
# (chol _|_ restecg, exang, age | sex, fbs, thalach, trestbps, heartdisease)
# (chol _|_ restecg, thalach, age | sex, fbs, exang, trestbps, heartdisease)
# (chol _|_ fbs, restecg, age | sex, thalach, exang, trestbps, heartdisease)
# (chol _|_ exang, sex | restecg, age, fbs, thalach, trestbps)
# (chol _|_ trestbps, exang, sex | restecg, age, fbs, thalach, heartdisease)
# (chol _|_ sex | restecg, age, fbs, exang, trestbps)
# (chol _|_ trestbps, thalach, sex | restecg, age, fbs, exang, heartdisease)
# (chol _|_ thalach, exang, sex | restecg, age, fbs, trestbps, heartdisease)
# (chol _|_ sex | restecg, age, thalach, exang, trestbps)
# (chol _|_ trestbps, fbs, sex | restecg, age, thalach, exang, heartdisease)
# (chol _|_ fbs, exang, sex | restecg, age, thalach, trestbps, heartdisease)
# (chol _|_ fbs, thalach, sex | restecg, age, exang, trestbps, heartdisease)
# (chol _|_ sex, age | restecg, fbs, thalach, exang, trestbps)
# (chol _|_ trestbps, sex, age | restecg, fbs, thalach, exang, heartdisease)
# (chol _|_ exang, sex, age | restecg, fbs, thalach, trestbps, heartdisease)
# (chol _|_ thalach, sex, age | restecg, fbs, exang, trestbps, heartdisease)
# (chol _|_ fbs, sex, age | restecg, thalach, exang, trestbps, heartdisease)
# (chol _|_ sex | age, fbs, thalach, exang, trestbps)
# (chol _|_ trestbps, restecg, sex | age, fbs, thalach, exang, heartdisease)
# (chol _|_ restecg, exang, sex | age, fbs, thalach, trestbps, heartdisease)
# (chol _|_ restecg, thalach, sex | age, fbs, exang, trestbps, heartdisease)
# (chol _|_ fbs, restecg, sex | age, thalach, exang, trestbps, heartdisease)
# (chol _|_ restecg, sex, age | fbs, thalach, exang, trestbps, heartdisease)
# (chol _|_ exang | sex, restecg, age, fbs, thalach, trestbps)
# (chol _|_ trestbps, exang | sex, restecg, age, fbs, thalach, heartdisease)
# (chol _|_ trestbps, thalach | sex, restecg, age, fbs, exang, heartdisease)
# (chol _|_ thalach, exang | sex, restecg, age, fbs, trestbps, heartdisease)
# (chol _|_ trestbps, fbs | sex, restecg, age, thalach, exang, heartdisease)
# (chol _|_ fbs, exang | sex, restecg, age, thalach, trestbps, heartdisease)
# (chol _|_ fbs, thalach | sex, restecg, age, exang, trestbps, heartdisease)
# (chol _|_ age | sex, restecg, fbs, thalach, exang, trestbps)
# (chol _|_ trestbps, age | sex, restecg, fbs, thalach, exang, heartdisease)
# (chol _|_ exang, age | sex, restecg, fbs, thalach, trestbps, heartdisease)
# (chol _|_ thalach, age | sex, restecg, fbs, exang, trestbps, heartdisease)
# (chol _|_ fbs, age | sex, restecg, thalach, exang, trestbps, heartdisease)
# (chol _|_ trestbps, restecg | sex, age, fbs, thalach, exang, heartdisease)
# (chol _|_ restecg, exang | sex, age, fbs, thalach, trestbps, heartdisease)
# (chol _|_ restecg, thalach | sex, age, fbs, exang, trestbps, heartdisease)
# (chol _|_ fbs, restecg | sex, age, thalach, exang, trestbps, heartdisease)
# (chol _|_ restecg, age | sex, fbs, thalach, exang, trestbps, heartdisease)
# (chol _|_ sex | restecg, age, fbs, thalach, exang, trestbps)
# (chol _|_ trestbps, sex | restecg, age, fbs, thalach, exang, heartdisease)
# (chol _|_ exang, sex | restecg, age, fbs, thalach, trestbps, heartdisease)
# (chol _|_ thalach, sex | restecg, age, fbs, exang, trestbps, heartdisease)
# (chol _|_ fbs, sex | restecg, age, thalach, exang, trestbps, heartdisease)
# (chol _|_ sex, age | restecg, fbs, thalach, exang, trestbps, heartdisease)
# (chol _|_ restecg, sex | age, fbs, thalach, exang, trestbps, heartdisease)
# (chol _|_ trestbps | sex, restecg, age, fbs, thalach, exang, heartdisease)
# (chol _|_ exang | sex, restecg, age, fbs, thalach, trestbps, heartdisease)
# (chol _|_ thalach | sex, restecg, age, fbs, exang, trestbps, heartdisease)
# (chol _|_ fbs | sex, restecg, age, thalach, exang, trestbps, heartdisease)
# (chol _|_ age | sex, restecg, fbs, thalach, exang, trestbps, heartdisease)
# (chol _|_ restecg | sex, age, fbs, thalach, exang, trestbps, heartdisease)
# (chol _|_ sex | restecg, age, fbs, thalach, exang, trestbps, heartdisease)

# %% [markdown]
# ###### Inferencing with Bayesian Network

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
heart_disease_infer = VariableElimination(model)

# Computing the probability of bronc given smoke.
query = heart_disease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(query)
# Out:
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<00:00, 1932.99it/s]
# Eliminating: restecg: 100%|██████████| 7/7 [00:00<00:00, 219.51it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.4919 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.5081 |
# +-----------------+---------------------+

# %%
# Out:
# <style> div.prompt_container{ width: 0px; min-width: 0px; visibility: collapse}</style>
# <style> div.prompt{ width: 0px; min-width: 0px; visibility: collapse}</style>
# <style> div.output pre { font-style: italic; color: rgb(105,105,105) } </style>
# <style>.container { width:100% !important; }</style>
